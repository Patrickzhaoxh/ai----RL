# %%
class SumTree:
    def __init__(self, capacity):
        self.capacity = capacity
        self.tree = np.zeros(2 * capacity - 1, dtype=np.float32)
        self.data = np.empty(capacity, dtype=object)
        self.ptr = 0
        self.n_entries = 0

    def _propagate(self, idx, change):
        parent = (idx - 1) // 2
        self.tree[parent] += change
        if parent != 0:
            self._propagate(parent, change)

    def update(self, idx, priority):
        change = priority - self.tree[idx]
        self.tree[idx] = priority
        self._propagate(idx, change)

    def add(self, priority, data):
        if data is None:
            priority = 0.0
        idx = self.ptr + self.capacity - 1
        self.data[self.ptr] = data
        self.update(idx, priority)
        self.ptr = (self.ptr + 1) % self.capacity
        self.n_entries = min(self.n_entries + 1, self.capacity)

    def _retrieve(self, idx, value):
        left = 2 * idx + 1
        right = left + 1
        if left >= len(self.tree):
            return idx
        if value <= self.tree[left]:
            return self._retrieve(left, value)
        else:
            return self._retrieve(right, value - self.tree[left])

    def sample(self, batch_size):
        segment = self.tree[0] / batch_size
        batch_idx, priorities, data = [], [], []
        for i in range(batch_size):
            a, b = segment * i, segment * (i + 1)
            value = random.uniform(a, b)
            idx = self._retrieve(0, value)
            tree_idx = idx - self.capacity + 1
            batch_idx.append(tree_idx)
            priorities.append(self.tree[idx])
            data.append(self.data[tree_idx])
        return batch_idx, np.array(priorities, dtype=np.float32), data
    @property
    def total(self):
        return self.tree[0]

# %%
import os
import random
from collections import deque, namedtuple
import numpy as np
import cv2
import gymnasium as gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from typing import Tuple
import ale_py
class AtariPreprocess:
    def __init__(self, width=84, height=84):
        self.width = width
        self.height = height

    def __call__(self, obs):
        img = cv2.cvtColor(obs, cv2.COLOR_RGB2GRAY)
        img = cv2.resize(img, (self.width, self.height), interpolation=cv2.INTER_AREA)
        return np.ascontiguousarray(img, dtype=np.uint8)

class FrameStack:
    def __init__(self, k):
        self.k = k
        self.frames = deque(maxlen=k)

    def reset(self, frame):
        for _ in range(self.k):
            self.frames.append(frame)
        return self._get_obs()

    def append(self, frame):
        self.frames.append(frame)
        return self._get_obs()

    def _get_obs(self):
        return np.stack(self.frames, axis=0)

class SkipEnvWrapper(gym.Wrapper):
    def __init__(self, env, skip=4):
        super().__init__(env)
        self.skip = skip

    def step(self, action):
        total_reward = 0.0
        done = False
        for i in range(self.skip):
            obs, reward, terminated, truncated, info = self.env.step(action)
            total_reward += reward
            done = terminated or truncated
            if done:
                break
        return obs, total_reward, terminated, truncated, info

def make_env(env_id="ALE/air_raid-v5", seed=0, skip=4, stack=4):
    raw = gym.make(env_id, render_mode=None)
    raw.reset(seed=seed)
    pre = AtariPreprocess()
    skipw = SkipEnvWrapper(raw, skip=skip)
    stacker = FrameStack(stack)
    class EnvObj:
        def __init__(self, e, pre, stacker):
            self.e = e
            self.pre = pre
            self.stacker = stacker
            self.action_space = e.action_space
            self.observation_space = gym.spaces.Box(
                low=0, high=255, shape=(stacker.k, pre.height, pre.width), dtype=np.uint8
            )

        def reset(self):
            obs, info = self.e.reset()
            obs_proc = self.pre(obs)
            stacked = self.stacker.reset(obs_proc)
            return stacked, info

        def step(self, action):
            obs, reward, terminated, truncated, info = self.e.step(action)
            obs_proc = self.pre(obs)
            stacked = self.stacker.append(obs_proc)
            reward = np.clip(reward, -1.0, 1.0)
            return stacked, reward, terminated, truncated, info

        def render(self, *args, **kwargs):
            return self.e.render(*args, **kwargs)

        def close(self):
            return self.e.close()

    return EnvObj(skipw, pre, stacker)

Transition = namedtuple('Transition', ('state', 'action', 'reward', 'next_state', 'done'))

class PrioritizedReplayBuffer:
    def __init__(self, capacity, device, alpha=0.6, beta=0.4, beta_increment=1e-6, eps=1e-6):
        self.tree = SumTree(capacity)
        self.device = device
        self.alpha = alpha
        self.beta = beta
        self.beta_increment = beta_increment
        self.eps = eps
        self.max_priority = 1.0

    def push(self, *args):
        self.tree.add(self.max_priority, Transition(*args))

    def sample(self, batch_size):
        idxs, priorities, batch = [], [], []
        while len(batch) < batch_size:
            i, p, d = self.tree.sample(1)
            if d[0] is None:
                continue
            idxs.extend(i)
            priorities.extend(p)
            batch.extend(d)
            if len(batch) == batch_size:
                break
        probs = np.array(priorities, dtype=np.float32) / self.tree.total
        self.beta = min(1.0, self.beta + self.beta_increment)
        weights = (probs * self.tree.n_entries) ** (-self.beta)
        weights /= weights.max()
        states = torch.from_numpy(np.stack([b.state for b in batch])).float().to(self.device) / 255.0
        actions = torch.tensor([b.action for b in batch], dtype=torch.long, device=self.device)
        rewards = torch.tensor([b.reward for b in batch], dtype=torch.float32, device=self.device)
        next_states = torch.from_numpy(np.stack([b.next_state for b in batch])).float().to(self.device) / 255.0
        dones = torch.tensor([float(b.done) for b in batch], dtype=torch.float32, device=self.device)
        weights = torch.from_numpy(weights.astype(np.float32)).to(self.device)
        return states, actions, rewards, next_states, dones, weights, idxs

    def update_priorities(self, idxs, td_errors):
        for idx, td in zip(idxs, td_errors):
            priority = (abs(td) + self.eps) ** self.alpha
            self.tree.update(idx + self.tree.capacity - 1, priority)
            self.max_priority = max(self.max_priority, priority)

    def __len__(self):
        return self.tree.n_entries

class DQN(nn.Module):
    def __init__(self, in_channels, n_actions):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels, 32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
        self._conv_out = self._get_conv_out(in_channels)
        self.fc1 = nn.Linear(self._conv_out, 512)
        self.fc2 = nn.Linear(512, n_actions)

    def _get_conv_out(self, in_channels):
        x = torch.zeros(1, in_channels, 84, 84)
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        return int(np.prod(x.size()))

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        return self.fc2(x)

class DQNAgent:
    def __init__(self, in_channels, n_actions, device, lr=1e-4, gamma=0.99,
                 buffer_size=100000, batch_size=32, target_update=1000,alpha=0.6,beta=0.4):
        self.device = device
        self.n_actions = n_actions
        self.gamma = gamma
        self.batch_size = batch_size
        self.target_update = target_update
        self.policy_net = DQN(in_channels, n_actions).to(device)
        self.target_net = DQN(in_channels, n_actions).to(device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=lr)
        self.replay = PrioritizedReplayBuffer(buffer_size, device,alpha=alpha, beta=beta)
        self.steps_done = 0

    def select_action(self, state, epsilon):
        if random.random() < epsilon:
            return random.randrange(self.n_actions)
        else:
            with torch.no_grad():
                s = torch.from_numpy(state).float().unsqueeze(0).to(self.device) / 255.0
                q = self.policy_net(s)
                return int(q.argmax(dim=1).item())

    def optimize(self):
        if len(self.replay) < self.batch_size:
            return None
        states, actions, rewards, next_states, dones, weights, idxs = self.replay.sample(self.batch_size)
        q_values = self.policy_net(states).gather(1, actions.unsqueeze(1)).squeeze(1)
        with torch.no_grad():
            next_actions = self.policy_net(next_states).argmax(1)
            next_q = self.target_net(next_states).gather(1, next_actions.unsqueeze(1)).squeeze(1)
            target_q = rewards + (1.0 - dones) * self.gamma * next_q
        td_errors = (q_values - target_q).detach().cpu().numpy()
        loss = (weights * F.smooth_l1_loss(q_values, target_q, reduction='none')).mean()
        self.optimizer.zero_grad()
        loss.backward()
        nn.utils.clip_grad_norm_(self.policy_net.parameters(), 10.0)
        self.optimizer.step()
        self.replay.update_priorities(idxs, td_errors)
        self.steps_done += 1
        if self.steps_done % self.target_update == 0:
            self.target_net.load_state_dict(self.policy_net.state_dict())
        return loss.item()

    def save(self, path):
        torch.save({
            'policy_state_dict': self.policy_net.state_dict(),
            'target_state_dict': self.target_net.state_dict(),
            'optimizer_state_dict': self.optimizer.state_dict(),
        }, path)

    def load(self, path):
        ck = torch.load(path, map_location=self.device)
        self.policy_net.load_state_dict(ck['policy_state_dict'])
        self.target_net.load_state_dict(ck['target_state_dict'])
        self.optimizer.load_state_dict(ck['optimizer_state_dict'])

def train(env_id='ALE/air_raid-v5',
          seed=42,
          total_steps=2_000_000,
          start_learning=50_000,
          eval_interval=50_000,
          save_path='dqn_airraid.pth'):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    env = make_env(env_id, seed=seed, skip=4, stack=4)
    eval_env = make_env(env_id, seed=seed+1, skip=4, stack=4)
    obs, _ = env.reset()
    in_channels = obs.shape[0]
    n_actions = env.action_space.n
    agent = DQNAgent(in_channels, n_actions, device,
                     lr=1e-4, gamma=0.99,
                     buffer_size=500000, batch_size=64, target_update=1000)
    epsilon_start = 1.0
    epsilon_final = 0.1
    epsilon_decay = 1_000_000
    state, _ = env.reset()
    episode_reward = 0.0
    episode_cnt = 0
    total_step = 0
    losses = []

    while total_step < total_steps:
        eps = epsilon_final + (epsilon_start - epsilon_final) * max(0, (epsilon_decay - total_step) / epsilon_decay)
        action = agent.select_action(state, eps)
        next_state, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        agent.replay.push(state, action, reward, next_state, done)
        state = next_state
        episode_reward += reward
        total_step += 1
        if len(agent.replay) >= start_learning:
            loss = agent.optimize()
            if loss is not None:
                losses.append(loss)
        if done:
            state, _ = env.reset()
            episode_cnt += 1
            print(f"Step {total_step} | Episode {episode_cnt} ended | Reward {episode_reward:.2f} | Eps {eps:.3f}")
            episode_reward = 0.0
        if total_step % eval_interval == 0:
            avg_score = evaluate(agent, eval_env, episodes=5)
            print(f"== Eval at step {total_step}: avg score = {avg_score:.2f} ==")
    agent.save(save_path)
    env.close()
    eval_env.close()

def evaluate(agent:DQNAgent, env, episodes=5, render=False):
    device = agent.device
    scores = []
    for ep in range(episodes):
        state, _ = env.reset()
        done = False
        total = 0.0
        while not done:
            action = agent.select_action(state, epsilon=0.001)  # near-greedy
            state, reward, terminated, truncated, info = env.step(action)
            total += reward
            done = terminated or truncated
            if render:
                env.render()
        scores.append(total)
    return float(np.mean(scores))


if __name__ == "__main__":
    train(env_id="ALE/AirRaid-v5",
          seed=123,
          total_steps=2_000_000,
          start_learning=50_000,
          eval_interval=50_000,
          save_path="dqn_airraid_final_improving.pth")
# Out:
# Step 156 | Episode 1 ended | Reward 5.00 | Eps 1.000
# Step 252 | Episode 2 ended | Reward 0.00 | Eps 1.000
# Step 347 | Episode 3 ended | Reward 5.00 | Eps 1.000
# Step 473 | Episode 4 ended | Reward 8.00 | Eps 1.000
# Step 666 | Episode 5 ended | Reward 10.00 | Eps 0.999
# Step 837 | Episode 6 ended | Reward 8.00 | Eps 0.999
# Step 1010 | Episode 7 ended | Reward 5.00 | Eps 0.999
# Step 1111 | Episode 8 ended | Reward 4.00 | Eps 0.999
# Step 1246 | Episode 9 ended | Reward 9.00 | Eps 0.999
# Step 1405 | Episode 10 ended | Reward 5.00 | Eps 0.999
# Step 1657 | Episode 11 ended | Reward 10.00 | Eps 0.999
# Step 1826 | Episode 12 ended | Reward 9.00 | Eps 0.998
# Step 2085 | Episode 13 ended | Reward 11.00 | Eps 0.998
# Step 2318 | Episode 14 ended | Reward 8.00 | Eps 0.998
# Step 2568 | Episode 15 ended | Reward 8.00 | Eps 0.998
# Step 2738 | Episode 16 ended | Reward 9.00 | Eps 0.998
# Step 2936 | Episode 17 ended | Reward 8.00 | Eps 0.997
# Step 3104 | Episode 18 ended | Reward 9.00 | Eps 0.997
# Step 3205 | Episode 19 ended | Reward 9.00 | Eps 0.997
# Step 3292 | Episode 20 ended | Reward 5.00 | Eps 0.997
# Step 3452 | Episode 21 ended | Reward 9.00 | Eps 0.997
# Step 3522 | Episode 22 ended | Reward 3.00 | Eps 0.997
# Step 3782 | Episode 23 ended | Reward 10.00 | Eps 0.997
# Step 4057 | Episode 24 ended | Reward 7.00 | Eps 0.996
# Step 4321 | Episode 25 ended | Reward 11.00 | Eps 0.996
# Step 4563 | Episode 26 ended | Reward 14.00 | Eps 0.996
# Step 4748 | Episode 27 ended | Reward 7.00 | Eps 0.996
# Step 4834 | Episode 28 ended | Reward 6.00 | Eps 0.996
# Step 4968 | Episode 29 ended | Reward 5.00 | Eps 0.996
# Step 5210 | Episode 30 ended | Reward 10.00 | Eps 0.995
# Step 5313 | Episode 31 ended | Reward 5.00 | Eps 0.995
# Step 5505 | Episode 32 ended | Reward 10.00 | Eps 0.995
# Step 5588 | Episode 33 ended | Reward 3.00 | Eps 0.995
# Step 5721 | Episode 34 ended | Reward 7.00 | Eps 0.995
# Step 5899 | Episode 35 ended | Reward 10.00 | Eps 0.995
# Step 6111 | Episode 36 ended | Reward 12.00 | Eps 0.995
# Step 6234 | Episode 37 ended | Reward 11.00 | Eps 0.994
# Step 6331 | Episode 38 ended | Reward 5.00 | Eps 0.994
# Step 6433 | Episode 39 ended | Reward 2.00 | Eps 0.994
# Step 6580 | Episode 40 ended | Reward 8.00 | Eps 0.994
# Step 6684 | Episode 41 ended | Reward 2.00 | Eps 0.994
# Step 6759 | Episode 42 ended | Reward 3.00 | Eps 0.994
# Step 6862 | Episode 43 ended | Reward 11.00 | Eps 0.994
# Step 6973 | Episode 44 ended | Reward 7.00 | Eps 0.994
# Step 7082 | Episode 45 ended | Reward 2.00 | Eps 0.994
# Step 7147 | Episode 46 ended | Reward 2.00 | Eps 0.994
# Step 7277 | Episode 47 ended | Reward 6.00 | Eps 0.993
# Step 7560 | Episode 48 ended | Reward 6.00 | Eps 0.993
# Step 7615 | Episode 49 ended | Reward 2.00 | Eps 0.993
# Step 7971 | Episode 50 ended | Reward 21.00 | Eps 0.993
# Step 8137 | Episode 51 ended | Reward 4.00 | Eps 0.993
# Step 8207 | Episode 52 ended | Reward 4.00 | Eps 0.993
# Step 8339 | Episode 53 ended | Reward 5.00 | Eps 0.992
# Step 8409 | Episode 54 ended | Reward 4.00 | Eps 0.992
# Step 8548 | Episode 55 ended | Reward 8.00 | Eps 0.992
# Step 8760 | Episode 56 ended | Reward 13.00 | Eps 0.992
# Step 8897 | Episode 57 ended | Reward 5.00 | Eps 0.992
# Step 9152 | Episode 58 ended | Reward 9.00 | Eps 0.992
# Step 9299 | Episode 59 ended | Reward 6.00 | Eps 0.992
# Step 9416 | Episode 60 ended | Reward 6.00 | Eps 0.992
# Step 9615 | Episode 61 ended | Reward 13.00 | Eps 0.991
# Step 9787 | Episode 62 ended | Reward 12.00 | Eps 0.991
# Step 9900 | Episode 63 ended | Reward 4.00 | Eps 0.991
# Step 10057 | Episode 64 ended | Reward 6.00 | Eps 0.991
# Step 10191 | Episode 65 ended | Reward 4.00 | Eps 0.991
# Step 10373 | Episode 66 ended | Reward 12.00 | Eps 0.991
# Step 10622 | Episode 67 ended | Reward 12.00 | Eps 0.990
# Step 10732 | Episode 68 ended | Reward 7.00 | Eps 0.990
# Step 11093 | Episode 69 ended | Reward 17.00 | Eps 0.990
# Step 11218 | Episode 70 ended | Reward 9.00 | Eps 0.990
# Step 11377 | Episode 71 ended | Reward 9.00 | Eps 0.990
# Step 11450 | Episode 72 ended | Reward 6.00 | Eps 0.990
# Step 11547 | Episode 73 ended | Reward 7.00 | Eps 0.990
# Step 11715 | Episode 74 ended | Reward 12.00 | Eps 0.989
# Step 11855 | Episode 75 ended | Reward 5.00 | Eps 0.989
# Step 12050 | Episode 76 ended | Reward 10.00 | Eps 0.989
# Step 12095 | Episode 77 ended | Reward 3.00 | Eps 0.989
# Step 12149 | Episode 78 ended | Reward 1.00 | Eps 0.989
# Step 12341 | Episode 79 ended | Reward 12.00 | Eps 0.989
# Step 12420 | Episode 80 ended | Reward 2.00 | Eps 0.989
# Step 12684 | Episode 81 ended | Reward 19.00 | Eps 0.989
# Step 12872 | Episode 82 ended | Reward 12.00 | Eps 0.988
# Step 13071 | Episode 83 ended | Reward 9.00 | Eps 0.988
# Step 13236 | Episode 84 ended | Reward 14.00 | Eps 0.988
# Step 13355 | Episode 85 ended | Reward 3.00 | Eps 0.988
# Step 13522 | Episode 86 ended | Reward 7.00 | Eps 0.988
# Step 13591 | Episode 87 ended | Reward 3.00 | Eps 0.988
# Step 13729 | Episode 88 ended | Reward 5.00 | Eps 0.988
# Step 13955 | Episode 89 ended | Reward 12.00 | Eps 0.987
# Step 14140 | Episode 90 ended | Reward 10.00 | Eps 0.987
# Step 14389 | Episode 91 ended | Reward 10.00 | Eps 0.987
# Step 14428 | Episode 92 ended | Reward 3.00 | Eps 0.987
# Step 14514 | Episode 93 ended | Reward 4.00 | Eps 0.987
# Step 14611 | Episode 94 ended | Reward 5.00 | Eps 0.987
# Step 14743 | Episode 95 ended | Reward 5.00 | Eps 0.987
# Step 14961 | Episode 96 ended | Reward 15.00 | Eps 0.987
# Step 15040 | Episode 97 ended | Reward 7.00 | Eps 0.986
# Step 15230 | Episode 98 ended | Reward 3.00 | Eps 0.986
# Step 15420 | Episode 99 ended | Reward 12.00 | Eps 0.986
# Step 15568 | Episode 100 ended | Reward 12.00 | Eps 0.986
# Step 15718 | Episode 101 ended | Reward 6.00 | Eps 0.986
# Step 15923 | Episode 102 ended | Reward 14.00 | Eps 0.986
# Step 16041 | Episode 103 ended | Reward 10.00 | Eps 0.986
# Step 16094 | Episode 104 ended | Reward 5.00 | Eps 0.986
# Step 16257 | Episode 105 ended | Reward 5.00 | Eps 0.985
# Step 16390 | Episode 106 ended | Reward 6.00 | Eps 0.985
# Step 16527 | Episode 107 ended | Reward 6.00 | Eps 0.985
# Step 16618 | Episode 108 ended | Reward 5.00 | Eps 0.985
# Step 16761 | Episode 109 ended | Reward 8.00 | Eps 0.985
# Step 16939 | Episode 110 ended | Reward 8.00 | Eps 0.985
# Step 17056 | Episode 111 ended | Reward 8.00 | Eps 0.985
# Step 17107 | Episode 112 ended | Reward 2.00 | Eps 0.985
# Step 17157 | Episode 113 ended | Reward 4.00 | Eps 0.985
# Step 17331 | Episode 114 ended | Reward 8.00 | Eps 0.984
# Step 17498 | Episode 115 ended | Reward 8.00 | Eps 0.984
# Step 17587 | Episode 116 ended | Reward 1.00 | Eps 0.984
# Step 17636 | Episode 117 ended | Reward 4.00 | Eps 0.984
# Step 17739 | Episode 118 ended | Reward 5.00 | Eps 0.984
# Step 17830 | Episode 119 ended | Reward 4.00 | Eps 0.984
# Step 17928 | Episode 120 ended | Reward 5.00 | Eps 0.984
# Step 18078 | Episode 121 ended | Reward 10.00 | Eps 0.984
# Step 18185 | Episode 122 ended | Reward 3.00 | Eps 0.984
# Step 18299 | Episode 123 ended | Reward 7.00 | Eps 0.984
# Step 18527 | Episode 124 ended | Reward 15.00 | Eps 0.983
# Step 18618 | Episode 125 ended | Reward 3.00 | Eps 0.983
# Step 19013 | Episode 126 ended | Reward 21.00 | Eps 0.983
# Step 19099 | Episode 127 ended | Reward 1.00 | Eps 0.983
# Step 19223 | Episode 128 ended | Reward 5.00 | Eps 0.983
# Step 19491 | Episode 129 ended | Reward 19.00 | Eps 0.982
# Step 19573 | Episode 130 ended | Reward 8.00 | Eps 0.982
# Step 19783 | Episode 131 ended | Reward 12.00 | Eps 0.982
# Step 19919 | Episode 132 ended | Reward 10.00 | Eps 0.982
# Step 20103 | Episode 133 ended | Reward 12.00 | Eps 0.982
# Step 20289 | Episode 134 ended | Reward 12.00 | Eps 0.982
# Step 20595 | Episode 135 ended | Reward 20.00 | Eps 0.981
# Step 20681 | Episode 136 ended | Reward 2.00 | Eps 0.981
# Step 20866 | Episode 137 ended | Reward 10.00 | Eps 0.981
# Step 21149 | Episode 138 ended | Reward 10.00 | Eps 0.981
# Step 21217 | Episode 139 ended | Reward 1.00 | Eps 0.981
# Step 21361 | Episode 140 ended | Reward 7.00 | Eps 0.981
# Step 21421 | Episode 141 ended | Reward 3.00 | Eps 0.981
# Step 21544 | Episode 142 ended | Reward 5.00 | Eps 0.981
# Step 21678 | Episode 143 ended | Reward 8.00 | Eps 0.980
# Step 21811 | Episode 144 ended | Reward 6.00 | Eps 0.980
# Step 22062 | Episode 145 ended | Reward 12.00 | Eps 0.980
# Step 22128 | Episode 146 ended | Reward 4.00 | Eps 0.980
# Step 22368 | Episode 147 ended | Reward 13.00 | Eps 0.980
# Step 22459 | Episode 148 ended | Reward 6.00 | Eps 0.980
# Step 22525 | Episode 149 ended | Reward 3.00 | Eps 0.980
# Step 22642 | Episode 150 ended | Reward 6.00 | Eps 0.980
# Step 22883 | Episode 151 ended | Reward 10.00 | Eps 0.979
# Step 23081 | Episode 152 ended | Reward 7.00 | Eps 0.979
# Step 23155 | Episode 153 ended | Reward 3.00 | Eps 0.979
# Step 23288 | Episode 154 ended | Reward 12.00 | Eps 0.979
# Step 23346 | Episode 155 ended | Reward 6.00 | Eps 0.979
# Step 23415 | Episode 156 ended | Reward 5.00 | Eps 0.979
# Step 23512 | Episode 157 ended | Reward 3.00 | Eps 0.979
# Step 23759 | Episode 158 ended | Reward 11.00 | Eps 0.979
# Step 24006 | Episode 159 ended | Reward 10.00 | Eps 0.978
# Step 24185 | Episode 160 ended | Reward 6.00 | Eps 0.978
# Step 24328 | Episode 161 ended | Reward 4.00 | Eps 0.978
# Step 24485 | Episode 162 ended | Reward 5.00 | Eps 0.978
# Step 24738 | Episode 163 ended | Reward 15.00 | Eps 0.978
# Step 24818 | Episode 164 ended | Reward 5.00 | Eps 0.978
# Step 24959 | Episode 165 ended | Reward 6.00 | Eps 0.978
# Step 25157 | Episode 166 ended | Reward 15.00 | Eps 0.977
# Step 25292 | Episode 167 ended | Reward 10.00 | Eps 0.977
# Step 25379 | Episode 168 ended | Reward 3.00 | Eps 0.977
# Step 25542 | Episode 169 ended | Reward 8.00 | Eps 0.977
# Step 25637 | Episode 170 ended | Reward 7.00 | Eps 0.977
# Step 25826 | Episode 171 ended | Reward 8.00 | Eps 0.977
# Step 25923 | Episode 172 ended | Reward 3.00 | Eps 0.977
# Step 26146 | Episode 173 ended | Reward 14.00 | Eps 0.976
# Step 26287 | Episode 174 ended | Reward 4.00 | Eps 0.976
# Step 26442 | Episode 175 ended | Reward 7.00 | Eps 0.976
# Step 26933 | Episode 176 ended | Reward 28.00 | Eps 0.976
# Step 27084 | Episode 177 ended | Reward 9.00 | Eps 0.976
# Step 27369 | Episode 178 ended | Reward 13.00 | Eps 0.975
# Step 27606 | Episode 179 ended | Reward 14.00 | Eps 0.975
# Step 27649 | Episode 180 ended | Reward 3.00 | Eps 0.975
# Step 27813 | Episode 181 ended | Reward 10.00 | Eps 0.975
# Step 28071 | Episode 182 ended | Reward 14.00 | Eps 0.975
# Step 28456 | Episode 183 ended | Reward 30.00 | Eps 0.974
# Step 28735 | Episode 184 ended | Reward 10.00 | Eps 0.974
# Step 28938 | Episode 185 ended | Reward 13.00 | Eps 0.974
# Step 29003 | Episode 186 ended | Reward 0.00 | Eps 0.974
# Step 29229 | Episode 187 ended | Reward 7.00 | Eps 0.974
# Step 29494 | Episode 188 ended | Reward 9.00 | Eps 0.973
# Step 29776 | Episode 189 ended | Reward 15.00 | Eps 0.973
# Step 29950 | Episode 190 ended | Reward 9.00 | Eps 0.973
# Step 30139 | Episode 191 ended | Reward 10.00 | Eps 0.973
# Step 30519 | Episode 192 ended | Reward 23.00 | Eps 0.973
# Step 30610 | Episode 193 ended | Reward 5.00 | Eps 0.972
# Step 30724 | Episode 194 ended | Reward 9.00 | Eps 0.972
# Step 30912 | Episode 195 ended | Reward 9.00 | Eps 0.972
# Step 31032 | Episode 196 ended | Reward 6.00 | Eps 0.972
# Step 31102 | Episode 197 ended | Reward 5.00 | Eps 0.972
# Step 31286 | Episode 198 ended | Reward 9.00 | Eps 0.972
# Step 31352 | Episode 199 ended | Reward 3.00 | Eps 0.972
# Step 31399 | Episode 200 ended | Reward 3.00 | Eps 0.972
# Step 31455 | Episode 201 ended | Reward 3.00 | Eps 0.972
# Step 31521 | Episode 202 ended | Reward 4.00 | Eps 0.972
# Step 31609 | Episode 203 ended | Reward 5.00 | Eps 0.972
# Step 31843 | Episode 204 ended | Reward 9.00 | Eps 0.971
# Step 31908 | Episode 205 ended | Reward 1.00 | Eps 0.971
# Step 32012 | Episode 206 ended | Reward 4.00 | Eps 0.971
# Step 32130 | Episode 207 ended | Reward 2.00 | Eps 0.971
# Step 32190 | Episode 208 ended | Reward 3.00 | Eps 0.971
# Step 32276 | Episode 209 ended | Reward 3.00 | Eps 0.971
# Step 32351 | Episode 210 ended | Reward 2.00 | Eps 0.971
# Step 32495 | Episode 211 ended | Reward 9.00 | Eps 0.971
# Step 32639 | Episode 212 ended | Reward 6.00 | Eps 0.971
# Step 32838 | Episode 213 ended | Reward 9.00 | Eps 0.970
# Step 32957 | Episode 214 ended | Reward 7.00 | Eps 0.970
# Step 33240 | Episode 215 ended | Reward 15.00 | Eps 0.970
# Step 33603 | Episode 216 ended | Reward 21.00 | Eps 0.970
# Step 33688 | Episode 217 ended | Reward 1.00 | Eps 0.970
# Step 33853 | Episode 218 ended | Reward 4.00 | Eps 0.970
# Step 33923 | Episode 219 ended | Reward 3.00 | Eps 0.969
# Step 33963 | Episode 220 ended | Reward 2.00 | Eps 0.969
# Step 34027 | Episode 221 ended | Reward 2.00 | Eps 0.969
# Step 34202 | Episode 222 ended | Reward 5.00 | Eps 0.969
# Step 34301 | Episode 223 ended | Reward 6.00 | Eps 0.969
# Step 34400 | Episode 224 ended | Reward 5.00 | Eps 0.969
# Step 34486 | Episode 225 ended | Reward 3.00 | Eps 0.969
# Step 35019 | Episode 226 ended | Reward 28.00 | Eps 0.968
# Step 35198 | Episode 227 ended | Reward 14.00 | Eps 0.968
# Step 35356 | Episode 228 ended | Reward 7.00 | Eps 0.968
# Step 35484 | Episode 229 ended | Reward 7.00 | Eps 0.968
# Step 35666 | Episode 230 ended | Reward 11.00 | Eps 0.968
# Step 35763 | Episode 231 ended | Reward 4.00 | Eps 0.968
# Step 35885 | Episode 232 ended | Reward 6.00 | Eps 0.968
# Step 36050 | Episode 233 ended | Reward 7.00 | Eps 0.968
# Step 36158 | Episode 234 ended | Reward 7.00 | Eps 0.967
# Step 36239 | Episode 235 ended | Reward 4.00 | Eps 0.967
# Step 36337 | Episode 236 ended | Reward 4.00 | Eps 0.967
# Step 36438 | Episode 237 ended | Reward 5.00 | Eps 0.967
# Step 36595 | Episode 238 ended | Reward 11.00 | Eps 0.967
# Step 36667 | Episode 239 ended | Reward 4.00 | Eps 0.967
# Step 36753 | Episode 240 ended | Reward 4.00 | Eps 0.967
# Step 36915 | Episode 241 ended | Reward 11.00 | Eps 0.967
# Step 36972 | Episode 242 ended | Reward 2.00 | Eps 0.967
# Step 37110 | Episode 243 ended | Reward 10.00 | Eps 0.967
# Step 37208 | Episode 244 ended | Reward 9.00 | Eps 0.967
# Step 37402 | Episode 245 ended | Reward 9.00 | Eps 0.966
# Step 37631 | Episode 246 ended | Reward 15.00 | Eps 0.966
# Step 37773 | Episode 247 ended | Reward 4.00 | Eps 0.966
# Step 37987 | Episode 248 ended | Reward 8.00 | Eps 0.966
# Step 38107 | Episode 249 ended | Reward 6.00 | Eps 0.966
# Step 38222 | Episode 250 ended | Reward 7.00 | Eps 0.966
# Step 38347 | Episode 251 ended | Reward 8.00 | Eps 0.965
# Step 38596 | Episode 252 ended | Reward 12.00 | Eps 0.965
# Step 38749 | Episode 253 ended | Reward 9.00 | Eps 0.965
# Step 38908 | Episode 254 ended | Reward 2.00 | Eps 0.965
# Step 39126 | Episode 255 ended | Reward 8.00 | Eps 0.965
# Step 39201 | Episode 256 ended | Reward 6.00 | Eps 0.965
# Step 39433 | Episode 257 ended | Reward 21.00 | Eps 0.965
# Step 39794 | Episode 258 ended | Reward 27.00 | Eps 0.964
# Step 39859 | Episode 259 ended | Reward 2.00 | Eps 0.964
# Step 40096 | Episode 260 ended | Reward 11.00 | Eps 0.964
# Step 40392 | Episode 261 ended | Reward 13.00 | Eps 0.964
# Step 40577 | Episode 262 ended | Reward 10.00 | Eps 0.963
# Step 40619 | Episode 263 ended | Reward 2.00 | Eps 0.963
# Step 40718 | Episode 264 ended | Reward 4.00 | Eps 0.963
# Step 40912 | Episode 265 ended | Reward 6.00 | Eps 0.963
# Step 41027 | Episode 266 ended | Reward 6.00 | Eps 0.963
# Step 41166 | Episode 267 ended | Reward 4.00 | Eps 0.963
# Step 41340 | Episode 268 ended | Reward 6.00 | Eps 0.963
# Step 41410 | Episode 269 ended | Reward 4.00 | Eps 0.963
# Step 41600 | Episode 270 ended | Reward 8.00 | Eps 0.963
# Step 41720 | Episode 271 ended | Reward 6.00 | Eps 0.962
# Step 41985 | Episode 272 ended | Reward 16.00 | Eps 0.962
# Step 42137 | Episode 273 ended | Reward 11.00 | Eps 0.962
# Step 42333 | Episode 274 ended | Reward 17.00 | Eps 0.962
# Step 42433 | Episode 275 ended | Reward 4.00 | Eps 0.962
# Step 42480 | Episode 276 ended | Reward 3.00 | Eps 0.962
# Step 42632 | Episode 277 ended | Reward 11.00 | Eps 0.962
# Step 42876 | Episode 278 ended | Reward 12.00 | Eps 0.961
# Step 42967 | Episode 279 ended | Reward 6.00 | Eps 0.961
# Step 43115 | Episode 280 ended | Reward 4.00 | Eps 0.961
# Step 43274 | Episode 281 ended | Reward 7.00 | Eps 0.961
# Step 43385 | Episode 282 ended | Reward 6.00 | Eps 0.961
# Step 43446 | Episode 283 ended | Reward 5.00 | Eps 0.961
# Step 43585 | Episode 284 ended | Reward 6.00 | Eps 0.961
# Step 43670 | Episode 285 ended | Reward 4.00 | Eps 0.961
# Step 43772 | Episode 286 ended | Reward 8.00 | Eps 0.961
# Step 43823 | Episode 287 ended | Reward 4.00 | Eps 0.961
# Step 43905 | Episode 288 ended | Reward 1.00 | Eps 0.960
# Step 44154 | Episode 289 ended | Reward 9.00 | Eps 0.960
# Step 44353 | Episode 290 ended | Reward 11.00 | Eps 0.960
# Step 44471 | Episode 291 ended | Reward 5.00 | Eps 0.960
# Step 44565 | Episode 292 ended | Reward 7.00 | Eps 0.960
# Step 44771 | Episode 293 ended | Reward 11.00 | Eps 0.960
# Step 44925 | Episode 294 ended | Reward 15.00 | Eps 0.960
# Step 45066 | Episode 295 ended | Reward 5.00 | Eps 0.959
# Step 45246 | Episode 296 ended | Reward 8.00 | Eps 0.959
# Step 45347 | Episode 297 ended | Reward 3.00 | Eps 0.959
# Step 45541 | Episode 298 ended | Reward 15.00 | Eps 0.959
# Step 45616 | Episode 299 ended | Reward 5.00 | Eps 0.959
# Step 45972 | Episode 300 ended | Reward 19.00 | Eps 0.959
# Step 46224 | Episode 301 ended | Reward 12.00 | Eps 0.958
# Step 46308 | Episode 302 ended | Reward 6.00 | Eps 0.958
# Step 46480 | Episode 303 ended | Reward 11.00 | Eps 0.958
# Step 46546 | Episode 304 ended | Reward 3.00 | Eps 0.958
# Step 46657 | Episode 305 ended | Reward 5.00 | Eps 0.958
# Step 46758 | Episode 306 ended | Reward 5.00 | Eps 0.958
# Step 46812 | Episode 307 ended | Reward 5.00 | Eps 0.958
# Step 47165 | Episode 308 ended | Reward 16.00 | Eps 0.958
# Step 47536 | Episode 309 ended | Reward 28.00 | Eps 0.957
# Step 47664 | Episode 310 ended | Reward 6.00 | Eps 0.957
# Step 47827 | Episode 311 ended | Reward 7.00 | Eps 0.957
# Step 47953 | Episode 312 ended | Reward 7.00 | Eps 0.957
# Step 48068 | Episode 313 ended | Reward 5.00 | Eps 0.957
# Step 48437 | Episode 314 ended | Reward 21.00 | Eps 0.956
# Step 49027 | Episode 315 ended | Reward 28.00 | Eps 0.956
# Step 49327 | Episode 316 ended | Reward 17.00 | Eps 0.956
# Step 49509 | Episode 317 ended | Reward 8.00 | Eps 0.955
# Step 49733 | Episode 318 ended | Reward 16.00 | Eps 0.955
# == Eval at step 50000: avg score = 4.20 ==
# Step 50034 | Episode 319 ended | Reward 15.00 | Eps 0.955
# Step 50167 | Episode 320 ended | Reward 6.00 | Eps 0.955
# Step 50256 | Episode 321 ended | Reward 4.00 | Eps 0.955
# Step 50390 | Episode 322 ended | Reward 5.00 | Eps 0.955
# Step 50462 | Episode 323 ended | Reward 1.00 | Eps 0.955
# Step 50647 | Episode 324 ended | Reward 6.00 | Eps 0.954
# Step 50776 | Episode 325 ended | Reward 10.00 | Eps 0.954
# Step 50955 | Episode 326 ended | Reward 10.00 | Eps 0.954
# Step 51174 | Episode 327 ended | Reward 9.00 | Eps 0.954
# Step 51282 | Episode 328 ended | Reward 9.00 | Eps 0.954
# Step 51505 | Episode 329 ended | Reward 8.00 | Eps 0.954
# Step 51687 | Episode 330 ended | Reward 8.00 | Eps 0.953
# Step 51823 | Episode 331 ended | Reward 11.00 | Eps 0.953
# Step 51977 | Episode 332 ended | Reward 9.00 | Eps 0.953
# Step 52091 | Episode 333 ended | Reward 5.00 | Eps 0.953
# Step 52176 | Episode 334 ended | Reward 5.00 | Eps 0.953
# Step 52339 | Episode 335 ended | Reward 7.00 | Eps 0.953
# Step 52595 | Episode 336 ended | Reward 13.00 | Eps 0.953
# Step 52684 | Episode 337 ended | Reward 3.00 | Eps 0.953
# Step 52888 | Episode 338 ended | Reward 14.00 | Eps 0.952
# Step 53013 | Episode 339 ended | Reward 3.00 | Eps 0.952
# Step 53123 | Episode 340 ended | Reward 4.00 | Eps 0.952
# Step 53323 | Episode 341 ended | Reward 10.00 | Eps 0.952
# Step 53521 | Episode 342 ended | Reward 11.00 | Eps 0.952
# Step 53628 | Episode 343 ended | Reward 4.00 | Eps 0.952
# Step 53727 | Episode 344 ended | Reward 1.00 | Eps 0.952
# Step 53922 | Episode 345 ended | Reward 16.00 | Eps 0.951
# Step 54077 | Episode 346 ended | Reward 11.00 | Eps 0.951
# Step 54206 | Episode 347 ended | Reward 8.00 | Eps 0.951
# Step 54409 | Episode 348 ended | Reward 8.00 | Eps 0.951
# Step 54501 | Episode 349 ended | Reward 5.00 | Eps 0.951
# Step 54595 | Episode 350 ended | Reward 7.00 | Eps 0.951
# Step 54695 | Episode 351 ended | Reward 6.00 | Eps 0.951
# Step 54788 | Episode 352 ended | Reward 3.00 | Eps 0.951
# Step 54862 | Episode 353 ended | Reward 3.00 | Eps 0.951
# Step 55020 | Episode 354 ended | Reward 7.00 | Eps 0.950
# Step 55245 | Episode 355 ended | Reward 11.00 | Eps 0.950
# Step 55348 | Episode 356 ended | Reward 6.00 | Eps 0.950
# Step 55653 | Episode 357 ended | Reward 20.00 | Eps 0.950
# Step 55741 | Episode 358 ended | Reward 5.00 | Eps 0.950
# Step 55823 | Episode 359 ended | Reward 4.00 | Eps 0.950
# Step 55956 | Episode 360 ended | Reward 9.00 | Eps 0.950
# Step 56101 | Episode 361 ended | Reward 7.00 | Eps 0.950
# Step 56171 | Episode 362 ended | Reward 2.00 | Eps 0.949
# Step 56371 | Episode 363 ended | Reward 14.00 | Eps 0.949
# Step 56628 | Episode 364 ended | Reward 12.00 | Eps 0.949
# Step 56698 | Episode 365 ended | Reward 3.00 | Eps 0.949
# Step 56872 | Episode 366 ended | Reward 15.00 | Eps 0.949
# Step 56982 | Episode 367 ended | Reward 7.00 | Eps 0.949
# Step 57144 | Episode 368 ended | Reward 13.00 | Eps 0.949
# Step 57260 | Episode 369 ended | Reward 4.00 | Eps 0.948
# Step 57505 | Episode 370 ended | Reward 13.00 | Eps 0.948
# Step 57684 | Episode 371 ended | Reward 9.00 | Eps 0.948
# Step 58145 | Episode 372 ended | Reward 24.00 | Eps 0.948
# Step 58482 | Episode 373 ended | Reward 10.00 | Eps 0.947
# Step 58729 | Episode 374 ended | Reward 14.00 | Eps 0.947
# Step 58865 | Episode 375 ended | Reward 13.00 | Eps 0.947
# Step 58943 | Episode 376 ended | Reward 1.00 | Eps 0.947
# Step 59062 | Episode 377 ended | Reward 7.00 | Eps 0.947
# Step 59161 | Episode 378 ended | Reward 5.00 | Eps 0.947
# Step 59469 | Episode 379 ended | Reward 16.00 | Eps 0.946
# Step 59522 | Episode 380 ended | Reward 3.00 | Eps 0.946
# Step 59686 | Episode 381 ended | Reward 9.00 | Eps 0.946
# Step 59789 | Episode 382 ended | Reward 6.00 | Eps 0.946
# Step 59923 | Episode 383 ended | Reward 7.00 | Eps 0.946
# Step 60091 | Episode 384 ended | Reward 5.00 | Eps 0.946
# Step 60200 | Episode 385 ended | Reward 7.00 | Eps 0.946
# Step 60415 | Episode 386 ended | Reward 10.00 | Eps 0.946
# Step 60524 | Episode 387 ended | Reward 8.00 | Eps 0.946
# Step 60715 | Episode 388 ended | Reward 12.00 | Eps 0.945
# Step 60844 | Episode 389 ended | Reward 5.00 | Eps 0.945
# Step 61071 | Episode 390 ended | Reward 9.00 | Eps 0.945
# Step 61126 | Episode 391 ended | Reward 4.00 | Eps 0.945
# Step 61245 | Episode 392 ended | Reward 12.00 | Eps 0.945
# Step 61336 | Episode 393 ended | Reward 6.00 | Eps 0.945
# Step 61525 | Episode 394 ended | Reward 13.00 | Eps 0.945
# Step 61611 | Episode 395 ended | Reward 6.00 | Eps 0.945
# Step 61755 | Episode 396 ended | Reward 6.00 | Eps 0.944
# Step 61865 | Episode 397 ended | Reward 4.00 | Eps 0.944
# Step 62028 | Episode 398 ended | Reward 13.00 | Eps 0.944
# Step 62170 | Episode 399 ended | Reward 7.00 | Eps 0.944
# Step 62226 | Episode 400 ended | Reward 1.00 | Eps 0.944
# Step 62305 | Episode 401 ended | Reward 5.00 | Eps 0.944
# Step 62466 | Episode 402 ended | Reward 9.00 | Eps 0.944
# Step 62731 | Episode 403 ended | Reward 10.00 | Eps 0.944
# Step 62856 | Episode 404 ended | Reward 7.00 | Eps 0.943
# Step 63074 | Episode 405 ended | Reward 8.00 | Eps 0.943
# Step 63447 | Episode 406 ended | Reward 20.00 | Eps 0.943
# Step 63605 | Episode 407 ended | Reward 7.00 | Eps 0.943
# Step 63690 | Episode 408 ended | Reward 5.00 | Eps 0.943
# Step 64214 | Episode 409 ended | Reward 23.00 | Eps 0.942
# Step 64262 | Episode 410 ended | Reward 1.00 | Eps 0.942
# Step 64429 | Episode 411 ended | Reward 10.00 | Eps 0.942
# Step 64576 | Episode 412 ended | Reward 3.00 | Eps 0.942
# Step 64698 | Episode 413 ended | Reward 5.00 | Eps 0.942
# Step 64771 | Episode 414 ended | Reward 4.00 | Eps 0.942
# Step 64877 | Episode 415 ended | Reward 4.00 | Eps 0.942
# Step 64972 | Episode 416 ended | Reward 2.00 | Eps 0.942
# Step 65205 | Episode 417 ended | Reward 11.00 | Eps 0.941
# Step 65433 | Episode 418 ended | Reward 8.00 | Eps 0.941
# Step 65526 | Episode 419 ended | Reward 5.00 | Eps 0.941
# Step 65683 | Episode 420 ended | Reward 12.00 | Eps 0.941
# Step 65935 | Episode 421 ended | Reward 11.00 | Eps 0.941
# Step 66067 | Episode 422 ended | Reward 6.00 | Eps 0.941
# Step 66153 | Episode 423 ended | Reward 4.00 | Eps 0.940
# Step 66292 | Episode 424 ended | Reward 11.00 | Eps 0.940
# Step 66475 | Episode 425 ended | Reward 9.00 | Eps 0.940
# Step 66925 | Episode 426 ended | Reward 20.00 | Eps 0.940
# Step 67030 | Episode 427 ended | Reward 8.00 | Eps 0.940
# Step 67157 | Episode 428 ended | Reward 7.00 | Eps 0.940
# Step 67515 | Episode 429 ended | Reward 14.00 | Eps 0.939
# Step 67854 | Episode 430 ended | Reward 14.00 | Eps 0.939
# Step 68018 | Episode 431 ended | Reward 8.00 | Eps 0.939
# Step 68286 | Episode 432 ended | Reward 15.00 | Eps 0.939
# Step 68569 | Episode 433 ended | Reward 13.00 | Eps 0.938
# Step 68775 | Episode 434 ended | Reward 7.00 | Eps 0.938
# Step 68957 | Episode 435 ended | Reward 15.00 | Eps 0.938
# Step 69086 | Episode 436 ended | Reward 7.00 | Eps 0.938
# Step 69200 | Episode 437 ended | Reward 7.00 | Eps 0.938
# Step 69396 | Episode 438 ended | Reward 9.00 | Eps 0.938
# Step 69625 | Episode 439 ended | Reward 10.00 | Eps 0.937
# Step 70057 | Episode 440 ended | Reward 28.00 | Eps 0.937
# Step 70562 | Episode 441 ended | Reward 24.00 | Eps 0.936
# Step 70795 | Episode 442 ended | Reward 12.00 | Eps 0.936
# Step 71074 | Episode 443 ended | Reward 22.00 | Eps 0.936
# Step 71172 | Episode 444 ended | Reward 5.00 | Eps 0.936
# Step 71394 | Episode 445 ended | Reward 14.00 | Eps 0.936
# Step 71491 | Episode 446 ended | Reward 6.00 | Eps 0.936
# Step 71660 | Episode 447 ended | Reward 14.00 | Eps 0.936
# Step 71785 | Episode 448 ended | Reward 7.00 | Eps 0.935
# Step 71956 | Episode 449 ended | Reward 7.00 | Eps 0.935
# Step 72029 | Episode 450 ended | Reward 4.00 | Eps 0.935
# Step 72173 | Episode 451 ended | Reward 8.00 | Eps 0.935
# Step 72295 | Episode 452 ended | Reward 7.00 | Eps 0.935
# Step 72343 | Episode 453 ended | Reward 0.00 | Eps 0.935
# Step 72486 | Episode 454 ended | Reward 11.00 | Eps 0.935
# Step 72599 | Episode 455 ended | Reward 7.00 | Eps 0.935
# Step 72653 | Episode 456 ended | Reward 2.00 | Eps 0.935
# Step 72876 | Episode 457 ended | Reward 10.00 | Eps 0.934
# Step 72994 | Episode 458 ended | Reward 8.00 | Eps 0.934
# Step 73175 | Episode 459 ended | Reward 12.00 | Eps 0.934
# Step 73338 | Episode 460 ended | Reward 6.00 | Eps 0.934
# Step 73473 | Episode 461 ended | Reward 9.00 | Eps 0.934
# Step 73565 | Episode 462 ended | Reward 2.00 | Eps 0.934
# Step 73664 | Episode 463 ended | Reward 1.00 | Eps 0.934
# Step 73844 | Episode 464 ended | Reward 9.00 | Eps 0.934
# Step 74098 | Episode 465 ended | Reward 14.00 | Eps 0.933
# Step 74286 | Episode 466 ended | Reward 7.00 | Eps 0.933
# Step 74355 | Episode 467 ended | Reward 4.00 | Eps 0.933
# Step 74511 | Episode 468 ended | Reward 9.00 | Eps 0.933
# Step 74559 | Episode 469 ended | Reward 4.00 | Eps 0.933
# Step 74622 | Episode 470 ended | Reward 2.00 | Eps 0.933
# Step 74757 | Episode 471 ended | Reward 13.00 | Eps 0.933
# Step 74946 | Episode 472 ended | Reward 9.00 | Eps 0.933
# Step 75028 | Episode 473 ended | Reward 5.00 | Eps 0.932
# Step 75169 | Episode 474 ended | Reward 8.00 | Eps 0.932
# Step 75300 | Episode 475 ended | Reward 3.00 | Eps 0.932
# Step 75436 | Episode 476 ended | Reward 9.00 | Eps 0.932
# Step 75609 | Episode 477 ended | Reward 10.00 | Eps 0.932
# Step 75815 | Episode 478 ended | Reward 14.00 | Eps 0.932
# Step 75969 | Episode 479 ended | Reward 13.00 | Eps 0.932
# Step 76076 | Episode 480 ended | Reward 4.00 | Eps 0.932
# Step 76269 | Episode 481 ended | Reward 11.00 | Eps 0.931
# Step 76375 | Episode 482 ended | Reward 6.00 | Eps 0.931
# Step 76489 | Episode 483 ended | Reward 5.00 | Eps 0.931
# Step 76555 | Episode 484 ended | Reward 4.00 | Eps 0.931
# Step 76695 | Episode 485 ended | Reward 12.00 | Eps 0.931
# Step 76862 | Episode 486 ended | Reward 9.00 | Eps 0.931
# Step 76979 | Episode 487 ended | Reward 4.00 | Eps 0.931
# Step 77042 | Episode 488 ended | Reward 4.00 | Eps 0.931
# Step 77202 | Episode 489 ended | Reward 10.00 | Eps 0.931
# Step 77268 | Episode 490 ended | Reward 1.00 | Eps 0.930
# Step 77421 | Episode 491 ended | Reward 10.00 | Eps 0.930
# Step 77480 | Episode 492 ended | Reward 4.00 | Eps 0.930
# Step 77588 | Episode 493 ended | Reward 8.00 | Eps 0.930
# Step 77696 | Episode 494 ended | Reward 5.00 | Eps 0.930
# Step 77817 | Episode 495 ended | Reward 7.00 | Eps 0.930
# Step 77983 | Episode 496 ended | Reward 4.00 | Eps 0.930
# Step 78165 | Episode 497 ended | Reward 6.00 | Eps 0.930
# Step 78333 | Episode 498 ended | Reward 8.00 | Eps 0.930
# Step 78393 | Episode 499 ended | Reward 3.00 | Eps 0.929
# Step 78530 | Episode 500 ended | Reward 4.00 | Eps 0.929
# Step 78706 | Episode 501 ended | Reward 11.00 | Eps 0.929
# Step 79073 | Episode 502 ended | Reward 27.00 | Eps 0.929
# Step 79164 | Episode 503 ended | Reward 9.00 | Eps 0.929
# Step 79327 | Episode 504 ended | Reward 10.00 | Eps 0.929
# Step 79487 | Episode 505 ended | Reward 7.00 | Eps 0.928
# Step 79578 | Episode 506 ended | Reward 7.00 | Eps 0.928
# Step 79669 | Episode 507 ended | Reward 4.00 | Eps 0.928
# Step 79766 | Episode 508 ended | Reward 6.00 | Eps 0.928
# Step 79941 | Episode 509 ended | Reward 15.00 | Eps 0.928
# Step 80089 | Episode 510 ended | Reward 10.00 | Eps 0.928
# Step 80214 | Episode 511 ended | Reward 7.00 | Eps 0.928
# Step 80322 | Episode 512 ended | Reward 7.00 | Eps 0.928
# Step 80531 | Episode 513 ended | Reward 13.00 | Eps 0.928
# Step 80940 | Episode 514 ended | Reward 19.00 | Eps 0.927
# Step 81235 | Episode 515 ended | Reward 15.00 | Eps 0.927
# Step 81616 | Episode 516 ended | Reward 28.00 | Eps 0.927
# Step 82029 | Episode 517 ended | Reward 24.00 | Eps 0.926
# Step 82084 | Episode 518 ended | Reward 2.00 | Eps 0.926
# Step 82142 | Episode 519 ended | Reward 5.00 | Eps 0.926
# Step 82189 | Episode 520 ended | Reward 1.00 | Eps 0.926
# Step 82329 | Episode 521 ended | Reward 10.00 | Eps 0.926
# Step 82407 | Episode 522 ended | Reward 5.00 | Eps 0.926
# Step 82574 | Episode 523 ended | Reward 7.00 | Eps 0.926
# Step 82678 | Episode 524 ended | Reward 3.00 | Eps 0.926
# Step 82808 | Episode 525 ended | Reward 4.00 | Eps 0.925
# Step 82953 | Episode 526 ended | Reward 14.00 | Eps 0.925
# Step 83150 | Episode 527 ended | Reward 9.00 | Eps 0.925
# Step 83411 | Episode 528 ended | Reward 15.00 | Eps 0.925
# Step 83528 | Episode 529 ended | Reward 9.00 | Eps 0.925
# Step 83675 | Episode 530 ended | Reward 4.00 | Eps 0.925
# Step 83840 | Episode 531 ended | Reward 5.00 | Eps 0.925
# Step 83905 | Episode 532 ended | Reward 1.00 | Eps 0.924
# Step 84095 | Episode 533 ended | Reward 15.00 | Eps 0.924
# Step 84348 | Episode 534 ended | Reward 13.00 | Eps 0.924
# Step 84532 | Episode 535 ended | Reward 13.00 | Eps 0.924
# Step 84646 | Episode 536 ended | Reward 4.00 | Eps 0.924
# Step 85065 | Episode 537 ended | Reward 24.00 | Eps 0.923
# Step 85143 | Episode 538 ended | Reward 4.00 | Eps 0.923
# Step 85379 | Episode 539 ended | Reward 13.00 | Eps 0.923
# Step 85550 | Episode 540 ended | Reward 7.00 | Eps 0.923
# Step 86039 | Episode 541 ended | Reward 27.00 | Eps 0.923
# Step 86084 | Episode 542 ended | Reward 2.00 | Eps 0.923
# Step 86199 | Episode 543 ended | Reward 7.00 | Eps 0.922
# Step 86431 | Episode 544 ended | Reward 9.00 | Eps 0.922
# Step 86500 | Episode 545 ended | Reward 3.00 | Eps 0.922
# Step 86651 | Episode 546 ended | Reward 7.00 | Eps 0.922
# Step 86795 | Episode 547 ended | Reward 12.00 | Eps 0.922
# Step 86846 | Episode 548 ended | Reward 4.00 | Eps 0.922
# Step 87189 | Episode 549 ended | Reward 20.00 | Eps 0.922
# Step 87411 | Episode 550 ended | Reward 15.00 | Eps 0.921
# Step 87555 | Episode 551 ended | Reward 5.00 | Eps 0.921
# Step 87677 | Episode 552 ended | Reward 8.00 | Eps 0.921
# Step 87841 | Episode 553 ended | Reward 6.00 | Eps 0.921
# Step 88096 | Episode 554 ended | Reward 13.00 | Eps 0.921
# Step 88138 | Episode 555 ended | Reward 2.00 | Eps 0.921
# Step 88477 | Episode 556 ended | Reward 18.00 | Eps 0.920
# Step 88565 | Episode 557 ended | Reward 3.00 | Eps 0.920
# Step 88688 | Episode 558 ended | Reward 8.00 | Eps 0.920
# Step 88839 | Episode 559 ended | Reward 9.00 | Eps 0.920
# Step 89070 | Episode 560 ended | Reward 10.00 | Eps 0.920
# Step 89309 | Episode 561 ended | Reward 11.00 | Eps 0.920
# Step 89454 | Episode 562 ended | Reward 7.00 | Eps 0.919
# Step 89572 | Episode 563 ended | Reward 8.00 | Eps 0.919
# Step 89767 | Episode 564 ended | Reward 16.00 | Eps 0.919
# Step 89852 | Episode 565 ended | Reward 4.00 | Eps 0.919
# Step 89952 | Episode 566 ended | Reward 6.00 | Eps 0.919
# Step 90213 | Episode 567 ended | Reward 12.00 | Eps 0.919
# Step 90319 | Episode 568 ended | Reward 5.00 | Eps 0.919
# Step 90415 | Episode 569 ended | Reward 3.00 | Eps 0.919
# Step 90687 | Episode 570 ended | Reward 17.00 | Eps 0.918
# Step 90817 | Episode 571 ended | Reward 9.00 | Eps 0.918
# Step 90910 | Episode 572 ended | Reward 5.00 | Eps 0.918
# Step 91064 | Episode 573 ended | Reward 9.00 | Eps 0.918
# Step 91180 | Episode 574 ended | Reward 7.00 | Eps 0.918
# Step 91553 | Episode 575 ended | Reward 22.00 | Eps 0.918
# Step 91606 | Episode 576 ended | Reward 7.00 | Eps 0.918
# Step 91682 | Episode 577 ended | Reward 5.00 | Eps 0.917
# Step 91823 | Episode 578 ended | Reward 9.00 | Eps 0.917
# Step 92037 | Episode 579 ended | Reward 14.00 | Eps 0.917
# Step 92092 | Episode 580 ended | Reward 2.00 | Eps 0.917
# Step 92280 | Episode 581 ended | Reward 14.00 | Eps 0.917
# Step 92400 | Episode 582 ended | Reward 6.00 | Eps 0.917
# Step 92497 | Episode 583 ended | Reward 3.00 | Eps 0.917
# Step 92674 | Episode 584 ended | Reward 9.00 | Eps 0.917
# Step 92723 | Episode 585 ended | Reward 4.00 | Eps 0.917
# Step 92851 | Episode 586 ended | Reward 8.00 | Eps 0.916
# Step 92998 | Episode 587 ended | Reward 4.00 | Eps 0.916
# Step 93186 | Episode 588 ended | Reward 8.00 | Eps 0.916
# Step 93296 | Episode 589 ended | Reward 5.00 | Eps 0.916
# Step 93458 | Episode 590 ended | Reward 8.00 | Eps 0.916
# Step 93606 | Episode 591 ended | Reward 9.00 | Eps 0.916
# Step 93708 | Episode 592 ended | Reward 4.00 | Eps 0.916
# Step 93943 | Episode 593 ended | Reward 12.00 | Eps 0.915
# Step 94149 | Episode 594 ended | Reward 10.00 | Eps 0.915
# Step 94315 | Episode 595 ended | Reward 7.00 | Eps 0.915
# Step 94481 | Episode 596 ended | Reward 9.00 | Eps 0.915
# Step 94584 | Episode 597 ended | Reward 3.00 | Eps 0.915
# Step 94723 | Episode 598 ended | Reward 6.00 | Eps 0.915
# Step 94872 | Episode 599 ended | Reward 10.00 | Eps 0.915
# Step 95069 | Episode 600 ended | Reward 12.00 | Eps 0.914
# Step 95500 | Episode 601 ended | Reward 24.00 | Eps 0.914
# Step 95718 | Episode 602 ended | Reward 10.00 | Eps 0.914
# Step 95924 | Episode 603 ended | Reward 14.00 | Eps 0.914
# Step 95969 | Episode 604 ended | Reward 5.00 | Eps 0.914
# Step 96105 | Episode 605 ended | Reward 10.00 | Eps 0.914
# Step 96287 | Episode 606 ended | Reward 5.00 | Eps 0.913
# Step 96521 | Episode 607 ended | Reward 15.00 | Eps 0.913
# Step 96637 | Episode 608 ended | Reward 4.00 | Eps 0.913
# Step 96747 | Episode 609 ended | Reward 6.00 | Eps 0.913
# Step 96872 | Episode 610 ended | Reward 10.00 | Eps 0.913
# Step 97074 | Episode 611 ended | Reward 15.00 | Eps 0.913
# Step 97183 | Episode 612 ended | Reward 8.00 | Eps 0.913
# Step 97363 | Episode 613 ended | Reward 10.00 | Eps 0.912
# Step 97634 | Episode 614 ended | Reward 15.00 | Eps 0.912
# Step 97732 | Episode 615 ended | Reward 3.00 | Eps 0.912
# Step 97904 | Episode 616 ended | Reward 7.00 | Eps 0.912
# Step 98036 | Episode 617 ended | Reward 8.00 | Eps 0.912
# Step 98320 | Episode 618 ended | Reward 14.00 | Eps 0.912
# Step 98382 | Episode 619 ended | Reward 2.00 | Eps 0.911
# Step 98452 | Episode 620 ended | Reward 2.00 | Eps 0.911
# Step 98553 | Episode 621 ended | Reward 6.00 | Eps 0.911
# Step 98636 | Episode 622 ended | Reward 3.00 | Eps 0.911
# Step 98762 | Episode 623 ended | Reward 7.00 | Eps 0.911
# Step 98979 | Episode 624 ended | Reward 13.00 | Eps 0.911
# Step 99241 | Episode 625 ended | Reward 14.00 | Eps 0.911
# Step 99330 | Episode 626 ended | Reward 4.00 | Eps 0.911
# Step 99509 | Episode 627 ended | Reward 13.00 | Eps 0.910
# Step 99725 | Episode 628 ended | Reward 10.00 | Eps 0.910
# Step 99929 | Episode 629 ended | Reward 10.00 | Eps 0.910
# == Eval at step 100000: avg score = 23.20 ==
# Step 100107 | Episode 630 ended | Reward 8.00 | Eps 0.910
# Step 100150 | Episode 631 ended | Reward 0.00 | Eps 0.910
# Step 100266 | Episode 632 ended | Reward 4.00 | Eps 0.910
# Step 100486 | Episode 633 ended | Reward 15.00 | Eps 0.910
# Step 100615 | Episode 634 ended | Reward 10.00 | Eps 0.909
# Step 100763 | Episode 635 ended | Reward 5.00 | Eps 0.909
# Step 100875 | Episode 636 ended | Reward 6.00 | Eps 0.909
# Step 101049 | Episode 637 ended | Reward 10.00 | Eps 0.909
# Step 101249 | Episode 638 ended | Reward 9.00 | Eps 0.909
# Step 101421 | Episode 639 ended | Reward 9.00 | Eps 0.909
# Step 101461 | Episode 640 ended | Reward 0.00 | Eps 0.909
# Step 101656 | Episode 641 ended | Reward 12.00 | Eps 0.909
# Step 101740 | Episode 642 ended | Reward 6.00 | Eps 0.908
# Step 101795 | Episode 643 ended | Reward 4.00 | Eps 0.908
# Step 101860 | Episode 644 ended | Reward 5.00 | Eps 0.908
# Step 102073 | Episode 645 ended | Reward 16.00 | Eps 0.908
# Step 102225 | Episode 646 ended | Reward 6.00 | Eps 0.908
# Step 102311 | Episode 647 ended | Reward 6.00 | Eps 0.908
# Step 102477 | Episode 648 ended | Reward 7.00 | Eps 0.908
# Step 102841 | Episode 649 ended | Reward 17.00 | Eps 0.907
# Step 102890 | Episode 650 ended | Reward 2.00 | Eps 0.907
# Step 103048 | Episode 651 ended | Reward 5.00 | Eps 0.907
# Step 103158 | Episode 652 ended | Reward 4.00 | Eps 0.907
# Step 103202 | Episode 653 ended | Reward 2.00 | Eps 0.907
# Step 103328 | Episode 654 ended | Reward 6.00 | Eps 0.907
# Step 103518 | Episode 655 ended | Reward 10.00 | Eps 0.907
# Step 103602 | Episode 656 ended | Reward 8.00 | Eps 0.907
# Step 103760 | Episode 657 ended | Reward 6.00 | Eps 0.907
# Step 104040 | Episode 658 ended | Reward 8.00 | Eps 0.906
# Step 104398 | Episode 659 ended | Reward 18.00 | Eps 0.906
# Step 104758 | Episode 660 ended | Reward 13.00 | Eps 0.906
# Step 104875 | Episode 661 ended | Reward 5.00 | Eps 0.906
# Step 104984 | Episode 662 ended | Reward 5.00 | Eps 0.906
# Step 105070 | Episode 663 ended | Reward 4.00 | Eps 0.905
# Step 105288 | Episode 664 ended | Reward 11.00 | Eps 0.905
# Step 105543 | Episode 665 ended | Reward 15.00 | Eps 0.905
# Step 105716 | Episode 666 ended | Reward 9.00 | Eps 0.905
# Step 105950 | Episode 667 ended | Reward 12.00 | Eps 0.905
# Step 106163 | Episode 668 ended | Reward 11.00 | Eps 0.904
# Step 106238 | Episode 669 ended | Reward 10.00 | Eps 0.904
# Step 106279 | Episode 670 ended | Reward 2.00 | Eps 0.904
# Step 106345 | Episode 671 ended | Reward 2.00 | Eps 0.904
# Step 106553 | Episode 672 ended | Reward 8.00 | Eps 0.904
# Step 106650 | Episode 673 ended | Reward 6.00 | Eps 0.904
# Step 106884 | Episode 674 ended | Reward 11.00 | Eps 0.904
# Step 107031 | Episode 675 ended | Reward 5.00 | Eps 0.904
# Step 107246 | Episode 676 ended | Reward 13.00 | Eps 0.903
# Step 107400 | Episode 677 ended | Reward 13.00 | Eps 0.903
# Step 107799 | Episode 678 ended | Reward 19.00 | Eps 0.903
# Step 107915 | Episode 679 ended | Reward 5.00 | Eps 0.903
# Step 108082 | Episode 680 ended | Reward 9.00 | Eps 0.903
# Step 108268 | Episode 681 ended | Reward 11.00 | Eps 0.903
# Step 108408 | Episode 682 ended | Reward 10.00 | Eps 0.902
# Step 108475 | Episode 683 ended | Reward 3.00 | Eps 0.902
# Step 108822 | Episode 684 ended | Reward 18.00 | Eps 0.902
# Step 109034 | Episode 685 ended | Reward 8.00 | Eps 0.902
# Step 109193 | Episode 686 ended | Reward 7.00 | Eps 0.902
# Step 109319 | Episode 687 ended | Reward 4.00 | Eps 0.902
# Step 109386 | Episode 688 ended | Reward 4.00 | Eps 0.902
# Step 109477 | Episode 689 ended | Reward 7.00 | Eps 0.901
# Step 109543 | Episode 690 ended | Reward 3.00 | Eps 0.901
# Step 109862 | Episode 691 ended | Reward 14.00 | Eps 0.901
# Step 109999 | Episode 692 ended | Reward 6.00 | Eps 0.901
# Step 110342 | Episode 693 ended | Reward 4.00 | Eps 0.901
# Step 110658 | Episode 694 ended | Reward 20.00 | Eps 0.900
# Step 110865 | Episode 695 ended | Reward 14.00 | Eps 0.900
# Step 110911 | Episode 696 ended | Reward 1.00 | Eps 0.900
# Step 110971 | Episode 697 ended | Reward 2.00 | Eps 0.900
# Step 111162 | Episode 698 ended | Reward 7.00 | Eps 0.900
# Step 111355 | Episode 699 ended | Reward 10.00 | Eps 0.900
# Step 111486 | Episode 700 ended | Reward 9.00 | Eps 0.900
# Step 111727 | Episode 701 ended | Reward 10.00 | Eps 0.899
# Step 111786 | Episode 702 ended | Reward 5.00 | Eps 0.899
# Step 111916 | Episode 703 ended | Reward 8.00 | Eps 0.899
# Step 112015 | Episode 704 ended | Reward 4.00 | Eps 0.899
# Step 112057 | Episode 705 ended | Reward 1.00 | Eps 0.899
# Step 112112 | Episode 706 ended | Reward 2.00 | Eps 0.899
# Step 112167 | Episode 707 ended | Reward 2.00 | Eps 0.899
# Step 112264 | Episode 708 ended | Reward 2.00 | Eps 0.899
# Step 112406 | Episode 709 ended | Reward 11.00 | Eps 0.899
# Step 112478 | Episode 710 ended | Reward 4.00 | Eps 0.899
# Step 112586 | Episode 711 ended | Reward 5.00 | Eps 0.899
# Step 112672 | Episode 712 ended | Reward 5.00 | Eps 0.899
# Step 112719 | Episode 713 ended | Reward 3.00 | Eps 0.899
# Step 112824 | Episode 714 ended | Reward 6.00 | Eps 0.898
# Step 112923 | Episode 715 ended | Reward 6.00 | Eps 0.898
# Step 112986 | Episode 716 ended | Reward 3.00 | Eps 0.898
# Step 113216 | Episode 717 ended | Reward 12.00 | Eps 0.898
# Step 113346 | Episode 718 ended | Reward 8.00 | Eps 0.898
# Step 113401 | Episode 719 ended | Reward 5.00 | Eps 0.898
# Step 113599 | Episode 720 ended | Reward 5.00 | Eps 0.898
# Step 113712 | Episode 721 ended | Reward 3.00 | Eps 0.898
# Step 113776 | Episode 722 ended | Reward 3.00 | Eps 0.898
# Step 113889 | Episode 723 ended | Reward 2.00 | Eps 0.898
# Step 113962 | Episode 724 ended | Reward 4.00 | Eps 0.897
# Step 114151 | Episode 725 ended | Reward 13.00 | Eps 0.897
# Step 114231 | Episode 726 ended | Reward 6.00 | Eps 0.897
# Step 114350 | Episode 727 ended | Reward 8.00 | Eps 0.897
# Step 114443 | Episode 728 ended | Reward 5.00 | Eps 0.897
# Step 114571 | Episode 729 ended | Reward 8.00 | Eps 0.897
# Step 114979 | Episode 730 ended | Reward 19.00 | Eps 0.897
# Step 115252 | Episode 731 ended | Reward 10.00 | Eps 0.896
# Step 115525 | Episode 732 ended | Reward 11.00 | Eps 0.896
# Step 115628 | Episode 733 ended | Reward 8.00 | Eps 0.896
# Step 115791 | Episode 734 ended | Reward 6.00 | Eps 0.896
# Step 115969 | Episode 735 ended | Reward 7.00 | Eps 0.896
# Step 116087 | Episode 736 ended | Reward 10.00 | Eps 0.896
# Step 116284 | Episode 737 ended | Reward 8.00 | Eps 0.895
# Step 116412 | Episode 738 ended | Reward 7.00 | Eps 0.895
# Step 116671 | Episode 739 ended | Reward 15.00 | Eps 0.895
# Step 116757 | Episode 740 ended | Reward 6.00 | Eps 0.895
# Step 116848 | Episode 741 ended | Reward 6.00 | Eps 0.895
# Step 116924 | Episode 742 ended | Reward 3.00 | Eps 0.895
# Step 117110 | Episode 743 ended | Reward 10.00 | Eps 0.895
# Step 117201 | Episode 744 ended | Reward 4.00 | Eps 0.895
# Step 117394 | Episode 745 ended | Reward 8.00 | Eps 0.894
# Step 117671 | Episode 746 ended | Reward 11.00 | Eps 0.894
# Step 117857 | Episode 747 ended | Reward 13.00 | Eps 0.894
# Step 118048 | Episode 748 ended | Reward 14.00 | Eps 0.894
# Step 118253 | Episode 749 ended | Reward 7.00 | Eps 0.894
# Step 118361 | Episode 750 ended | Reward 6.00 | Eps 0.893
# Step 118461 | Episode 751 ended | Reward 5.00 | Eps 0.893
# Step 119259 | Episode 752 ended | Reward 43.00 | Eps 0.893
# Step 119415 | Episode 753 ended | Reward 6.00 | Eps 0.893
# Step 119636 | Episode 754 ended | Reward 13.00 | Eps 0.892
# Step 119843 | Episode 755 ended | Reward 13.00 | Eps 0.892
# Step 120112 | Episode 756 ended | Reward 11.00 | Eps 0.892
# Step 120155 | Episode 757 ended | Reward 1.00 | Eps 0.892
# Step 120318 | Episode 758 ended | Reward 11.00 | Eps 0.892
# Step 120626 | Episode 759 ended | Reward 16.00 | Eps 0.891
# Step 120848 | Episode 760 ended | Reward 15.00 | Eps 0.891
# Step 120901 | Episode 761 ended | Reward 2.00 | Eps 0.891
# Step 121050 | Episode 762 ended | Reward 10.00 | Eps 0.891
# Step 121196 | Episode 763 ended | Reward 7.00 | Eps 0.891
# Step 121362 | Episode 764 ended | Reward 11.00 | Eps 0.891
# Step 121436 | Episode 765 ended | Reward 2.00 | Eps 0.891
# Step 121978 | Episode 766 ended | Reward 24.00 | Eps 0.890
# Step 122220 | Episode 767 ended | Reward 19.00 | Eps 0.890
# Step 122446 | Episode 768 ended | Reward 17.00 | Eps 0.890
# Step 122662 | Episode 769 ended | Reward 13.00 | Eps 0.890
# Step 122785 | Episode 770 ended | Reward 7.00 | Eps 0.889
# Step 122930 | Episode 771 ended | Reward 9.00 | Eps 0.889
# Step 123270 | Episode 772 ended | Reward 24.00 | Eps 0.889
# Step 123444 | Episode 773 ended | Reward 14.00 | Eps 0.889
# Step 123500 | Episode 774 ended | Reward 0.00 | Eps 0.889
# Step 123811 | Episode 775 ended | Reward 20.00 | Eps 0.889
# Step 123897 | Episode 776 ended | Reward 4.00 | Eps 0.888
# Step 123937 | Episode 777 ended | Reward 1.00 | Eps 0.888
# Step 124039 | Episode 778 ended | Reward 6.00 | Eps 0.888
# Step 124389 | Episode 779 ended | Reward 9.00 | Eps 0.888
# Step 124549 | Episode 780 ended | Reward 10.00 | Eps 0.888
# Step 124706 | Episode 781 ended | Reward 7.00 | Eps 0.888
# Step 124831 | Episode 782 ended | Reward 6.00 | Eps 0.888
# Step 124969 | Episode 783 ended | Reward 7.00 | Eps 0.888
# Step 125053 | Episode 784 ended | Reward 2.00 | Eps 0.887
# Step 125142 | Episode 785 ended | Reward 4.00 | Eps 0.887
# Step 125279 | Episode 786 ended | Reward 7.00 | Eps 0.887
# Step 125400 | Episode 787 ended | Reward 8.00 | Eps 0.887
# Step 125583 | Episode 788 ended | Reward 12.00 | Eps 0.887
# Step 125678 | Episode 789 ended | Reward 2.00 | Eps 0.887
# Step 126028 | Episode 790 ended | Reward 21.00 | Eps 0.887
# Step 126099 | Episode 791 ended | Reward 2.00 | Eps 0.887
# Step 126312 | Episode 792 ended | Reward 8.00 | Eps 0.886
# Step 126496 | Episode 793 ended | Reward 6.00 | Eps 0.886
# Step 126607 | Episode 794 ended | Reward 8.00 | Eps 0.886
# Step 126761 | Episode 795 ended | Reward 12.00 | Eps 0.886
# Step 127030 | Episode 796 ended | Reward 11.00 | Eps 0.886
# Step 127238 | Episode 797 ended | Reward 15.00 | Eps 0.885
# Step 127288 | Episode 798 ended | Reward 4.00 | Eps 0.885
# Step 127630 | Episode 799 ended | Reward 24.00 | Eps 0.885
# Step 127675 | Episode 800 ended | Reward 2.00 | Eps 0.885
# Step 127831 | Episode 801 ended | Reward 6.00 | Eps 0.885
# Step 127905 | Episode 802 ended | Reward 2.00 | Eps 0.885
# Step 127995 | Episode 803 ended | Reward 4.00 | Eps 0.885
# Step 128156 | Episode 804 ended | Reward 16.00 | Eps 0.885
# Step 128424 | Episode 805 ended | Reward 13.00 | Eps 0.884
# Step 128521 | Episode 806 ended | Reward 5.00 | Eps 0.884
# Step 128604 | Episode 807 ended | Reward 4.00 | Eps 0.884
# Step 128679 | Episode 808 ended | Reward 7.00 | Eps 0.884
# Step 128835 | Episode 809 ended | Reward 8.00 | Eps 0.884
# Step 129008 | Episode 810 ended | Reward 4.00 | Eps 0.884
# Step 129207 | Episode 811 ended | Reward 16.00 | Eps 0.884
# Step 129260 | Episode 812 ended | Reward 3.00 | Eps 0.884
# Step 129435 | Episode 813 ended | Reward 10.00 | Eps 0.884
# Step 129515 | Episode 814 ended | Reward 7.00 | Eps 0.883
# Step 129607 | Episode 815 ended | Reward 5.00 | Eps 0.883
# Step 129726 | Episode 816 ended | Reward 7.00 | Eps 0.883
# Step 129798 | Episode 817 ended | Reward 5.00 | Eps 0.883
# Step 130142 | Episode 818 ended | Reward 26.00 | Eps 0.883
# Step 130438 | Episode 819 ended | Reward 16.00 | Eps 0.883
# Step 130522 | Episode 820 ended | Reward 8.00 | Eps 0.883
# Step 130650 | Episode 821 ended | Reward 9.00 | Eps 0.882
# Step 130731 | Episode 822 ended | Reward 1.00 | Eps 0.882
# Step 130852 | Episode 823 ended | Reward 7.00 | Eps 0.882
# Step 131021 | Episode 824 ended | Reward 12.00 | Eps 0.882
# Step 131187 | Episode 825 ended | Reward 9.00 | Eps 0.882
# Step 131336 | Episode 826 ended | Reward 6.00 | Eps 0.882
# Step 131417 | Episode 827 ended | Reward 4.00 | Eps 0.882
# Step 131479 | Episode 828 ended | Reward 1.00 | Eps 0.882
# Step 131674 | Episode 829 ended | Reward 11.00 | Eps 0.881
# Step 131799 | Episode 830 ended | Reward 8.00 | Eps 0.881
# Step 131892 | Episode 831 ended | Reward 3.00 | Eps 0.881
# Step 132087 | Episode 832 ended | Reward 10.00 | Eps 0.881
# Step 132270 | Episode 833 ended | Reward 7.00 | Eps 0.881
# Step 132637 | Episode 834 ended | Reward 25.00 | Eps 0.881
# Step 132888 | Episode 835 ended | Reward 12.00 | Eps 0.880
# ...
# Step 1916116 | Episode 11724 ended | Reward 25.00 | Eps 0.100
# Step 1916491 | Episode 11725 ended | Reward 47.00 | Eps 0.100
# Step 1916582 | Episode 11726 ended | Reward 6.00 | Eps 0.100
# Step 1916875 | Episode 11727 ended | Reward 31.00 | Eps 0.100
# Step 1917345 | Episode 11728 ended | Reward 58.00 | Eps 0.100
# Step 1917557 | Episode 11729 ended | Reward 23.00 | Eps 0.100
# Step 1917748 | Episode 11730 ended | Reward 24.00 | Eps 0.100
# Step 1917980 | Episode 11731 ended | Reward 27.00 | Eps 0.100
# Step 1918133 | Episode 11732 ended | Reward 19.00 | Eps 0.100
# Step 1918440 | Episode 11733 ended | Reward 27.00 | Eps 0.100
# Step 1919050 | Episode 11734 ended | Reward 65.00 | Eps 0.100
# Step 1919583 | Episode 11735 ended | Reward 54.00 | Eps 0.100
# Step 1920063 | Episode 11736 ended | Reward 49.00 | Eps 0.100
# Step 1920284 | Episode 11737 ended | Reward 24.00 | Eps 0.100
# Step 1920856 | Episode 11738 ended | Reward 70.00 | Eps 0.100
# Step 1921341 | Episode 11739 ended | Reward 60.00 | Eps 0.100
# Step 1921634 | Episode 11740 ended | Reward 30.00 | Eps 0.100
# Step 1921745 | Episode 11741 ended | Reward 17.00 | Eps 0.100
# Step 1921997 | Episode 11742 ended | Reward 30.00 | Eps 0.100
# Step 1922386 | Episode 11743 ended | Reward 45.00 | Eps 0.100
# Step 1922523 | Episode 11744 ended | Reward 12.00 | Eps 0.100
# Step 1922727 | Episode 11745 ended | Reward 31.00 | Eps 0.100
# Step 1923098 | Episode 11746 ended | Reward 51.00 | Eps 0.100
# Step 1923331 | Episode 11747 ended | Reward 31.00 | Eps 0.100
# Step 1924081 | Episode 11748 ended | Reward 93.00 | Eps 0.100
# Step 1924249 | Episode 11749 ended | Reward 15.00 | Eps 0.100
# Step 1924339 | Episode 11750 ended | Reward 11.00 | Eps 0.100
# Step 1924798 | Episode 11751 ended | Reward 57.00 | Eps 0.100
# Step 1925011 | Episode 11752 ended | Reward 26.00 | Eps 0.100
# Step 1925285 | Episode 11753 ended | Reward 33.00 | Eps 0.100
# Step 1925404 | Episode 11754 ended | Reward 16.00 | Eps 0.100
# Step 1925618 | Episode 11755 ended | Reward 26.00 | Eps 0.100
# Step 1925743 | Episode 11756 ended | Reward 12.00 | Eps 0.100
# Step 1926052 | Episode 11757 ended | Reward 31.00 | Eps 0.100
# Step 1926582 | Episode 11758 ended | Reward 61.00 | Eps 0.100
# Step 1926934 | Episode 11759 ended | Reward 41.00 | Eps 0.100
# Step 1927042 | Episode 11760 ended | Reward 13.00 | Eps 0.100
# Step 1927556 | Episode 11761 ended | Reward 53.00 | Eps 0.100
# Step 1927756 | Episode 11762 ended | Reward 25.00 | Eps 0.100
# Step 1928164 | Episode 11763 ended | Reward 43.00 | Eps 0.100
# Step 1928733 | Episode 11764 ended | Reward 63.00 | Eps 0.100
# Step 1929199 | Episode 11765 ended | Reward 59.00 | Eps 0.100
# Step 1929324 | Episode 11766 ended | Reward 15.00 | Eps 0.100
# Step 1929564 | Episode 11767 ended | Reward 29.00 | Eps 0.100
# Step 1929652 | Episode 11768 ended | Reward 14.00 | Eps 0.100
# Step 1929939 | Episode 11769 ended | Reward 32.00 | Eps 0.100
# Step 1930329 | Episode 11770 ended | Reward 48.00 | Eps 0.100
# Step 1930412 | Episode 11771 ended | Reward 7.00 | Eps 0.100
# Step 1930897 | Episode 11772 ended | Reward 40.00 | Eps 0.100
# Step 1931362 | Episode 11773 ended | Reward 54.00 | Eps 0.100
# Step 1932091 | Episode 11774 ended | Reward 91.00 | Eps 0.100
# Step 1932440 | Episode 11775 ended | Reward 36.00 | Eps 0.100
# Step 1932773 | Episode 11776 ended | Reward 34.00 | Eps 0.100
# Step 1933004 | Episode 11777 ended | Reward 27.00 | Eps 0.100
# Step 1933361 | Episode 11778 ended | Reward 48.00 | Eps 0.100
# Step 1933751 | Episode 11779 ended | Reward 42.00 | Eps 0.100
# Step 1933974 | Episode 11780 ended | Reward 28.00 | Eps 0.100
# Step 1934038 | Episode 11781 ended | Reward 7.00 | Eps 0.100
# Step 1934630 | Episode 11782 ended | Reward 77.00 | Eps 0.100
# Step 1934883 | Episode 11783 ended | Reward 25.00 | Eps 0.100
# Step 1935125 | Episode 11784 ended | Reward 23.00 | Eps 0.100
# Step 1935541 | Episode 11785 ended | Reward 44.00 | Eps 0.100
# Step 1935617 | Episode 11786 ended | Reward 10.00 | Eps 0.100
# Step 1935726 | Episode 11787 ended | Reward 12.00 | Eps 0.100
# Step 1935901 | Episode 11788 ended | Reward 22.00 | Eps 0.100
# Step 1936569 | Episode 11789 ended | Reward 74.00 | Eps 0.100
# Step 1936649 | Episode 11790 ended | Reward 10.00 | Eps 0.100
# Step 1936716 | Episode 11791 ended | Reward 8.00 | Eps 0.100
# Step 1936921 | Episode 11792 ended | Reward 23.00 | Eps 0.100
# Step 1937172 | Episode 11793 ended | Reward 29.00 | Eps 0.100
# Step 1937512 | Episode 11794 ended | Reward 43.00 | Eps 0.100
# Step 1937746 | Episode 11795 ended | Reward 22.00 | Eps 0.100
# Step 1938162 | Episode 11796 ended | Reward 50.00 | Eps 0.100
# Step 1938270 | Episode 11797 ended | Reward 13.00 | Eps 0.100
# Step 1938448 | Episode 11798 ended | Reward 18.00 | Eps 0.100
# Step 1938779 | Episode 11799 ended | Reward 45.00 | Eps 0.100
# Step 1938867 | Episode 11800 ended | Reward 10.00 | Eps 0.100
# Step 1939504 | Episode 11801 ended | Reward 78.00 | Eps 0.100
# Step 1940033 | Episode 11802 ended | Reward 69.00 | Eps 0.100
# Step 1940175 | Episode 11803 ended | Reward 17.00 | Eps 0.100
# Step 1940417 | Episode 11804 ended | Reward 25.00 | Eps 0.100
# Step 1940684 | Episode 11805 ended | Reward 22.00 | Eps 0.100
# Step 1941125 | Episode 11806 ended | Reward 38.00 | Eps 0.100
# Step 1941278 | Episode 11807 ended | Reward 17.00 | Eps 0.100
# Step 1941774 | Episode 11808 ended | Reward 56.00 | Eps 0.100
# Step 1942299 | Episode 11809 ended | Reward 62.00 | Eps 0.100
# Step 1942431 | Episode 11810 ended | Reward 18.00 | Eps 0.100
# Step 1943022 | Episode 11811 ended | Reward 70.00 | Eps 0.100
# Step 1943178 | Episode 11812 ended | Reward 16.00 | Eps 0.100
# Step 1943584 | Episode 11813 ended | Reward 45.00 | Eps 0.100
# Step 1943714 | Episode 11814 ended | Reward 11.00 | Eps 0.100
# Step 1943801 | Episode 11815 ended | Reward 7.00 | Eps 0.100
# Step 1944267 | Episode 11816 ended | Reward 53.00 | Eps 0.100
# Step 1944830 | Episode 11817 ended | Reward 64.00 | Eps 0.100
# Step 1945095 | Episode 11818 ended | Reward 28.00 | Eps 0.100
# Step 1945378 | Episode 11819 ended | Reward 24.00 | Eps 0.100
# Step 1945716 | Episode 11820 ended | Reward 37.00 | Eps 0.100
# Step 1946586 | Episode 11821 ended | Reward 108.00 | Eps 0.100
# Step 1947180 | Episode 11822 ended | Reward 79.00 | Eps 0.100
# Step 1947472 | Episode 11823 ended | Reward 28.00 | Eps 0.100
# Step 1947581 | Episode 11824 ended | Reward 11.00 | Eps 0.100
# Step 1947720 | Episode 11825 ended | Reward 16.00 | Eps 0.100
# Step 1948085 | Episode 11826 ended | Reward 40.00 | Eps 0.100
# Step 1948243 | Episode 11827 ended | Reward 14.00 | Eps 0.100
# Step 1948331 | Episode 11828 ended | Reward 8.00 | Eps 0.100
# Step 1948581 | Episode 11829 ended | Reward 25.00 | Eps 0.100
# Step 1949533 | Episode 11830 ended | Reward 123.00 | Eps 0.100
# Step 1949732 | Episode 11831 ended | Reward 25.00 | Eps 0.100
# Step 1949974 | Episode 11832 ended | Reward 25.00 | Eps 0.100
# == Eval at step 1950000: avg score = 55.20 ==
# Step 1950167 | Episode 11833 ended | Reward 27.00 | Eps 0.100
# Step 1950287 | Episode 11834 ended | Reward 13.00 | Eps 0.100
# Step 1950667 | Episode 11835 ended | Reward 44.00 | Eps 0.100
# Step 1950888 | Episode 11836 ended | Reward 28.00 | Eps 0.100
# Step 1950965 | Episode 11837 ended | Reward 7.00 | Eps 0.100
# Step 1951506 | Episode 11838 ended | Reward 65.00 | Eps 0.100
# Step 1951828 | Episode 11839 ended | Reward 48.00 | Eps 0.100
# Step 1952437 | Episode 11840 ended | Reward 64.00 | Eps 0.100
# Step 1952739 | Episode 11841 ended | Reward 32.00 | Eps 0.100
# Step 1953009 | Episode 11842 ended | Reward 33.00 | Eps 0.100
# Step 1953321 | Episode 11843 ended | Reward 36.00 | Eps 0.100
# Step 1953591 | Episode 11844 ended | Reward 32.00 | Eps 0.100
# Step 1953908 | Episode 11845 ended | Reward 41.00 | Eps 0.100
# Step 1954135 | Episode 11846 ended | Reward 30.00 | Eps 0.100
# Step 1954339 | Episode 11847 ended | Reward 26.00 | Eps 0.100
# Step 1954625 | Episode 11848 ended | Reward 31.00 | Eps 0.100
# Step 1954770 | Episode 11849 ended | Reward 17.00 | Eps 0.100
# Step 1954891 | Episode 11850 ended | Reward 13.00 | Eps 0.100
# Step 1955032 | Episode 11851 ended | Reward 17.00 | Eps 0.100
# Step 1955205 | Episode 11852 ended | Reward 17.00 | Eps 0.100
# Step 1955431 | Episode 11853 ended | Reward 28.00 | Eps 0.100
# Step 1955753 | Episode 11854 ended | Reward 38.00 | Eps 0.100
# Step 1956156 | Episode 11855 ended | Reward 47.00 | Eps 0.100
# Step 1956686 | Episode 11856 ended | Reward 64.00 | Eps 0.100
# Step 1957051 | Episode 11857 ended | Reward 46.00 | Eps 0.100
# Step 1957382 | Episode 11858 ended | Reward 36.00 | Eps 0.100
# Step 1957912 | Episode 11859 ended | Reward 68.00 | Eps 0.100
# Step 1958188 | Episode 11860 ended | Reward 28.00 | Eps 0.100
# Step 1958456 | Episode 11861 ended | Reward 30.00 | Eps 0.100
# Step 1958597 | Episode 11862 ended | Reward 19.00 | Eps 0.100
# Step 1958941 | Episode 11863 ended | Reward 41.00 | Eps 0.100
# Step 1959213 | Episode 11864 ended | Reward 32.00 | Eps 0.100
# Step 1959411 | Episode 11865 ended | Reward 25.00 | Eps 0.100
# Step 1959593 | Episode 11866 ended | Reward 17.00 | Eps 0.100
# Step 1960024 | Episode 11867 ended | Reward 51.00 | Eps 0.100
# Step 1960146 | Episode 11868 ended | Reward 10.00 | Eps 0.100
# Step 1960344 | Episode 11869 ended | Reward 22.00 | Eps 0.100
# Step 1960446 | Episode 11870 ended | Reward 8.00 | Eps 0.100
# Step 1960497 | Episode 11871 ended | Reward 7.00 | Eps 0.100
# Step 1960554 | Episode 11872 ended | Reward 6.00 | Eps 0.100
# Step 1960999 | Episode 11873 ended | Reward 49.00 | Eps 0.100
# Step 1961250 | Episode 11874 ended | Reward 25.00 | Eps 0.100
# Step 1961343 | Episode 11875 ended | Reward 11.00 | Eps 0.100
# Step 1961462 | Episode 11876 ended | Reward 17.00 | Eps 0.100
# Step 1961574 | Episode 11877 ended | Reward 17.00 | Eps 0.100
# Step 1962012 | Episode 11878 ended | Reward 60.00 | Eps 0.100
# Step 1962321 | Episode 11879 ended | Reward 42.00 | Eps 0.100
# Step 1962566 | Episode 11880 ended | Reward 32.00 | Eps 0.100
# Step 1963032 | Episode 11881 ended | Reward 47.00 | Eps 0.100
# Step 1963312 | Episode 11882 ended | Reward 33.00 | Eps 0.100
# Step 1963881 | Episode 11883 ended | Reward 71.00 | Eps 0.100
# Step 1964282 | Episode 11884 ended | Reward 44.00 | Eps 0.100
# Step 1964440 | Episode 11885 ended | Reward 15.00 | Eps 0.100
# Step 1965082 | Episode 11886 ended | Reward 70.00 | Eps 0.100
# Step 1965467 | Episode 11887 ended | Reward 38.00 | Eps 0.100
# Step 1965860 | Episode 11888 ended | Reward 37.00 | Eps 0.100
# Step 1966061 | Episode 11889 ended | Reward 24.00 | Eps 0.100
# Step 1966930 | Episode 11890 ended | Reward 96.00 | Eps 0.100
# Step 1967705 | Episode 11891 ended | Reward 93.00 | Eps 0.100
# Step 1967787 | Episode 11892 ended | Reward 13.00 | Eps 0.100
# Step 1968109 | Episode 11893 ended | Reward 41.00 | Eps 0.100
# Step 1968240 | Episode 11894 ended | Reward 13.00 | Eps 0.100
# Step 1968375 | Episode 11895 ended | Reward 13.00 | Eps 0.100
# Step 1968601 | Episode 11896 ended | Reward 25.00 | Eps 0.100
# Step 1968898 | Episode 11897 ended | Reward 37.00 | Eps 0.100
# Step 1969110 | Episode 11898 ended | Reward 25.00 | Eps 0.100
# Step 1969562 | Episode 11899 ended | Reward 60.00 | Eps 0.100
# Step 1969768 | Episode 11900 ended | Reward 21.00 | Eps 0.100
# Step 1969977 | Episode 11901 ended | Reward 27.00 | Eps 0.100
# Step 1970171 | Episode 11902 ended | Reward 23.00 | Eps 0.100
# Step 1970512 | Episode 11903 ended | Reward 42.00 | Eps 0.100
# Step 1970736 | Episode 11904 ended | Reward 35.00 | Eps 0.100
# Step 1970906 | Episode 11905 ended | Reward 20.00 | Eps 0.100
# Step 1971425 | Episode 11906 ended | Reward 62.00 | Eps 0.100
# Step 1971897 | Episode 11907 ended | Reward 61.00 | Eps 0.100
# Step 1972120 | Episode 11908 ended | Reward 31.00 | Eps 0.100
# Step 1972377 | Episode 11909 ended | Reward 28.00 | Eps 0.100
# Step 1972947 | Episode 11910 ended | Reward 70.00 | Eps 0.100
# Step 1973502 | Episode 11911 ended | Reward 60.00 | Eps 0.100
# Step 1974023 | Episode 11912 ended | Reward 58.00 | Eps 0.100
# Step 1974189 | Episode 11913 ended | Reward 23.00 | Eps 0.100
# Step 1974582 | Episode 11914 ended | Reward 44.00 | Eps 0.100
# Step 1974845 | Episode 11915 ended | Reward 26.00 | Eps 0.100
# Step 1975087 | Episode 11916 ended | Reward 30.00 | Eps 0.100
# Step 1975320 | Episode 11917 ended | Reward 27.00 | Eps 0.100
# Step 1975564 | Episode 11918 ended | Reward 30.00 | Eps 0.100
# Step 1975878 | Episode 11919 ended | Reward 32.00 | Eps 0.100
# Step 1976327 | Episode 11920 ended | Reward 54.00 | Eps 0.100
# Step 1976705 | Episode 11921 ended | Reward 42.00 | Eps 0.100
# Step 1977114 | Episode 11922 ended | Reward 58.00 | Eps 0.100
# Step 1977344 | Episode 11923 ended | Reward 21.00 | Eps 0.100
# Step 1977905 | Episode 11924 ended | Reward 73.00 | Eps 0.100
# Step 1978327 | Episode 11925 ended | Reward 45.00 | Eps 0.100
# Step 1978716 | Episode 11926 ended | Reward 42.00 | Eps 0.100
# Step 1979662 | Episode 11927 ended | Reward 104.00 | Eps 0.100
# Step 1980168 | Episode 11928 ended | Reward 54.00 | Eps 0.100
# Step 1980488 | Episode 11929 ended | Reward 42.00 | Eps 0.100
# Step 1981070 | Episode 11930 ended | Reward 73.00 | Eps 0.100
# Step 1981612 | Episode 11931 ended | Reward 58.00 | Eps 0.100
# Step 1981804 | Episode 11932 ended | Reward 22.00 | Eps 0.100
# Step 1982405 | Episode 11933 ended | Reward 74.00 | Eps 0.100
# Step 1982596 | Episode 11934 ended | Reward 17.00 | Eps 0.100
# Step 1982731 | Episode 11935 ended | Reward 18.00 | Eps 0.100
# Step 1983249 | Episode 11936 ended | Reward 60.00 | Eps 0.100
# Step 1983322 | Episode 11937 ended | Reward 8.00 | Eps 0.100
# Step 1983571 | Episode 11938 ended | Reward 30.00 | Eps 0.100
# Step 1983822 | Episode 11939 ended | Reward 28.00 | Eps 0.100
# Step 1984456 | Episode 11940 ended | Reward 74.00 | Eps 0.100
# Step 1985007 | Episode 11941 ended | Reward 55.00 | Eps 0.100
# Step 1985325 | Episode 11942 ended | Reward 35.00 | Eps 0.100
# Step 1985695 | Episode 11943 ended | Reward 47.00 | Eps 0.100
# Step 1986023 | Episode 11944 ended | Reward 40.00 | Eps 0.100
# Step 1986334 | Episode 11945 ended | Reward 37.00 | Eps 0.100
# Step 1986860 | Episode 11946 ended | Reward 55.00 | Eps 0.100
# Step 1987860 | Episode 11947 ended | Reward 119.00 | Eps 0.100
# Step 1988096 | Episode 11948 ended | Reward 28.00 | Eps 0.100
# Step 1988583 | Episode 11949 ended | Reward 63.00 | Eps 0.100
# Step 1988946 | Episode 11950 ended | Reward 50.00 | Eps 0.100
# Step 1988996 | Episode 11951 ended | Reward 4.00 | Eps 0.100
# Step 1989385 | Episode 11952 ended | Reward 45.00 | Eps 0.100
# Step 1990115 | Episode 11953 ended | Reward 77.00 | Eps 0.100
# Step 1990203 | Episode 11954 ended | Reward 12.00 | Eps 0.100
# Step 1990503 | Episode 11955 ended | Reward 36.00 | Eps 0.100
# Step 1990645 | Episode 11956 ended | Reward 18.00 | Eps 0.100
# Step 1991288 | Episode 11957 ended | Reward 78.00 | Eps 0.100
# Step 1991906 | Episode 11958 ended | Reward 70.00 | Eps 0.100
# Step 1992209 | Episode 11959 ended | Reward 31.00 | Eps 0.100
# Step 1992488 | Episode 11960 ended | Reward 32.00 | Eps 0.100
# Step 1993114 | Episode 11961 ended | Reward 80.00 | Eps 0.100
# Step 1993218 | Episode 11962 ended | Reward 12.00 | Eps 0.100
# Step 1994041 | Episode 11963 ended | Reward 93.00 | Eps 0.100
# Step 1994198 | Episode 11964 ended | Reward 14.00 | Eps 0.100
# Step 1994603 | Episode 11965 ended | Reward 38.00 | Eps 0.100
# Step 1994924 | Episode 11966 ended | Reward 37.00 | Eps 0.100
# Step 1995614 | Episode 11967 ended | Reward 85.00 | Eps 0.100
# Step 1996185 | Episode 11968 ended | Reward 80.00 | Eps 0.100
# Step 1996367 | Episode 11969 ended | Reward 25.00 | Eps 0.100
# Step 1996620 | Episode 11970 ended | Reward 31.00 | Eps 0.100
# Step 1996834 | Episode 11971 ended | Reward 22.00 | Eps 0.100
# Step 1997172 | Episode 11972 ended | Reward 48.00 | Eps 0.100
# Step 1997727 | Episode 11973 ended | Reward 56.00 | Eps 0.100
# Step 1997997 | Episode 11974 ended | Reward 32.00 | Eps 0.100
# Step 1998316 | Episode 11975 ended | Reward 43.00 | Eps 0.100
# Step 1998423 | Episode 11976 ended | Reward 10.00 | Eps 0.100
# Step 1998781 | Episode 11977 ended | Reward 42.00 | Eps 0.100
# Step 1999093 | Episode 11978 ended | Reward 36.00 | Eps 0.100
# Step 1999351 | Episode 11979 ended | Reward 33.00 | Eps 0.100
# == Eval at step 2000000: avg score = 59.00 ==

# %%
import gymnasium as gym
import torch
import numpy as np
import ale_py

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

env = make_env(env_id="ALE/AirRaid-v5", seed=114514, skip=4, stack=4)
env.e = gym.make("ALE/AirRaid-v5", render_mode="human")
num_actions = env.action_space.n
obs, _ = env.reset()
in_channels = obs.shape[0]
policy_net = DQN(in_channels,num_actions).to(device)
checkpoint = torch.load("models/dqn_airraid_final_improving.pth", map_location=device)
policy_net.load_state_dict(checkpoint['policy_state_dict'])
policy_net.eval()
episodes = 3
for ep in range(episodes):
    state, _ = env.reset()
    done = False
    score = 0
    while not done:
        s = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0) / 255.0
        with torch.no_grad():
            q_values = policy_net(s)
            action = q_values.argmax(1).item()
        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        state = next_state
        score += reward
        env.render()
    print(f"Episode {ep+1} finished, score = {score}")

env.close()
# Out:
# C:\Users\18735\AppData\Local\Temp\ipykernel_7568\707549297.py:14: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load("dqn_airraid_final_improving.pth", map_location=device)
# Episode 1 finished, score = 6.0
# Episode 2 finished, score = 18.0
# Episode 3 finished, score = 3.0
